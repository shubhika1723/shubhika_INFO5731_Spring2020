# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhika1723/shubhika_INFO5731_Spring2020/blob/main/two_INFO5731_Assignment_Three_fall2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment.

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as all the 100 reviews (abstracts, or tweets).

# %%
# Write your code here
#installing selenium package
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,524 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,342 kB]
# Get:16 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [2,235 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,568 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [3,099 kB]
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [1,143 kB]
# Fetched 14.2 MB in 9s (1,607 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 22 not upgraded.
# Need to get 95.6 MB of archives.
# After this operation, 321 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 108.0.5359.71-0ubuntu0.18.04.5 [1,159 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 108.0.5359.71-0ubuntu0.18.04.5 [83.6 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 108.0.5359.71-0ubuntu0.18.04.5 [5,230 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 108.0.5359.71-0ubuntu0.18.04.5 [5,594 kB]
# Fetched 95.6 MB in 4s (22.9 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 124016 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_108.0.5359.71-0ubuntu0.18.04.5_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (108.0.5359.71-0ubuntu0.18.04.5) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_108.0.5359.71-0ubuntu0.18.04.5_amd64.deb ...
# Unpacking chromium-browser (108.0.5359.71-0ubuntu0.18.04.5) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_108.0.5359.71-0ubuntu0.18.04.5_all.deb ...
# Unpacking chromium-browser-l10n (108.0.5359.71-0ubuntu0.18.04.5) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_108.0.5359.71-0ubuntu0.18.04.5_amd64.deb ...
# Unpacking chromium-chromedriver (108.0.5359.71-0ubuntu0.18.04.5) ...
# Setting up chromium-codecs-ffmpeg-extra (108.0.5359.71-0ubuntu0.18.04.5) ...
# Setting up chromium-browser (108.0.5359.71-0ubuntu0.18.04.5) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (108.0.5359.71-0ubuntu0.18.04.5) ...
# Setting up chromium-browser-l10n (108.0.5359.71-0ubuntu0.18.04.5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting selenium
#   Downloading selenium-4.7.2-py3-none-any.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 5.1 MB/s
# Collecting urllib3[socks]~=1.26
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 54.0 MB/s
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
#      |████████████████████████████████| 384 kB 36.2 MB/s
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.8/dist-packages (from selenium) (2022.9.24)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting exceptiongroup>=1.0.0rc9
#   Downloading exceptiongroup-1.0.4-py3-none-any.whl (14 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (2.10)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (22.1.0)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 4.7 MB/s
# Installing collected packages: sniffio, outcome, h11, exceptiongroup, async-generator, wsproto, urllib3, trio, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.13 which is incompatible.
# Successfully installed async-generator-1.10 exceptiongroup-1.0.4 h11-0.14.0 outcome-1.2.0 selenium-4.7.2 sniffio-1.3.0 trio-0.22.0 trio-websocket-0.9.2 urllib3-1.26.13 wsproto-1.2.0

# %%
from selenium import webdriver #importing selenium package
options = webdriver.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %%
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.by import By
import pandas as pd
import time

driver = webdriver.Chrome('chromedriver',options=options)
link = 'https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv'
title_array = []
review_array = []
driver.get(link)
for num in range(4):
  driver.find_element(By.CLASS_NAME,"ipl-load-more__button").click()
  time.sleep(5)
  listOfTitle = driver.find_elements(By.CLASS_NAME, "title")
  listOfReviews = driver.find_elements(By.CLASS_NAME, "text")
for ele, sub_ele in zip(listOfTitle, listOfReviews):
      title_array.append((ele.text).replace('\n',''))
      review_array.append(sub_ele.text)
df = pd.DataFrame(list(zip(title_array, review_array)), columns =['Title', 'Review'])
print("Length of data frame is {0}".format(len(df)))
df
# Out:
# Length of data frame is 125
#                                                  Title  \
# 0        I would not call it a masterpiece as some did
# 1        Not a spoon feeding of CGI fueled faux drama.
# 2                           Is it great? I don't know.
# 3                             Perfect in every aspect.
# 4    A psychological study, rather than a superhero...
# ..                                                 ...
# 120                            There Are No Capes Here
# 121  If you're an outcast, you'll understand this m...
# 122                   An experience as much as a movie
# 123  Incredible movie! And one of the best 2019 mov...
# 124                                       Scarily real
#
#                                                 Review
# 0
# 1    The movie affects you in a way that makes it p...
# 2    When I heard everyone saying that this is the ...
# 3    Truly a masterpiece, The Best Hollywood film o...
# 4    I have seen Joker yesterday at Venice an early...
# ..                                                 ...
# 120  Joaquin Phoenix transforms into the titular ch...
# 121  And I'm not saying you need to be a freak. Man...
# 122  Saw this at the cinema and came out speechless...
# 123  This is the movie where the audience will like...
# 124  First just to say that I would officially rate...
#
# [125 rows x 2 columns]

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Package abc is already up-to-date!
#        | Downloading package alpino to /root/nltk_data...
#        |   Package alpino is already up-to-date!
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Package averaged_perceptron_tagger is already up-to-date!
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Package averaged_perceptron_tagger_ru is already up-to-
#        |       date!
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Package basque_grammars is already up-to-date!
#        | Downloading package bcp47 to /root/nltk_data...
#        |   Package bcp47 is already up-to-date!
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Package biocreative_ppi is already up-to-date!
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Package bllip_wsj_no_aux is already up-to-date!
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Package book_grammars is already up-to-date!
#        | Downloading package brown to /root/nltk_data...
#        |   Package brown is already up-to-date!
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Package brown_tei is already up-to-date!
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Package cess_cat is already up-to-date!
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Package cess_esp is already up-to-date!
#        | Downloading package chat80 to /root/nltk_data...
#        |   Package chat80 is already up-to-date!
#        | Downloading package city_database to /root/nltk_data...
#        |   Package city_database is already up-to-date!
#        | Downloading package cmudict to /root/nltk_data...
#        |   Package cmudict is already up-to-date!
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Package comparative_sentences is already up-to-date!
#        | Downloading package comtrans to /root/nltk_data...
#        |   Package comtrans is already up-to-date!
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Package conll2000 is already up-to-date!
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Package conll2002 is already up-to-date!
#        | Downloading package conll2007 to /root/nltk_data...
#        |   Package conll2007 is already up-to-date!
#        | Downloading package crubadan to /root/nltk_data...
#        |   Package crubadan is already up-to-date!
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Package dependency_treebank is already up-to-date!
#        | Downloading package dolch to /root/nltk_data...
#        |   Package dolch is already up-to-date!
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Package europarl_raw is already up-to-date!
#        | Downloading package extended_omw to /root/nltk_data...
#        |   Package extended_omw is already up-to-date!
#        | Downloading package floresta to /root/nltk_data...
#        |   Package floresta is already up-to-date!
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Package framenet_v15 is already up-to-date!
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Package framenet_v17 is already up-to-date!
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Package gazetteers is already up-to-date!
#        | Downloading package genesis to /root/nltk_data...
#        |   Package genesis is already up-to-date!
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Package gutenberg is already up-to-date!
#        | Downloading package ieer to /root/nltk_data...
#        |   Package ieer is already up-to-date!
#        | Downloading package inaugural to /root/nltk_data...
#        |   Package inaugural is already up-to-date!
#        | Downloading package indian to /root/nltk_data...
#        |   Package indian is already up-to-date!
#        | Downloading package jeita to /root/nltk_data...
#        |   Package jeita is already up-to-date!
#        | Downloading package kimmo to /root/nltk_data...
#        |   Package kimmo is already up-to-date!
#        | Downloading package knbc to /root/nltk_data...
#        |   Package knbc is already up-to-date!
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Package large_grammars is already up-to-date!
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Package lin_thesaurus is already up-to-date!
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Package mac_morpho is already up-to-date!
#        | Downloading package machado to /root/nltk_data...
#        |   Package machado is already up-to-date!
#        | Downloading package masc_tagged to /root/nltk_data...
#        |   Package masc_tagged is already up-to-date!
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Package maxent_ne_chunker is already up-to-date!
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Package maxent_treebank_pos_tagger is already up-to-date!
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Package moses_sample is already up-to-date!
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Package movie_reviews is already up-to-date!
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Package mte_teip5 is already up-to-date!
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Package mwa_ppdb is already up-to-date!
#        | Downloading package names to /root/nltk_data...
#        |   Package names is already up-to-date!
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        |   Package nombank.1.0 is already up-to-date!
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Package nonbreaking_prefixes is already up-to-date!
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Package nps_chat is already up-to-date!
#        | Downloading package omw to /root/nltk_data...
#        |   Package omw is already up-to-date!
#        | Downloading package omw-1.4 to /root/nltk_data...
#        |   Package omw-1.4 is already up-to-date!
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Package opinion_lexicon is already up-to-date!
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        |   Package panlex_swadesh is already up-to-date!
#        | Downloading package paradigms to /root/nltk_data...
#        |   Package paradigms is already up-to-date!
#        | Downloading package pe08 to /root/nltk_data...
#        |   Package pe08 is already up-to-date!
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Package perluniprops is already up-to-date!
#        | Downloading package pil to /root/nltk_data...
#        |   Package pil is already up-to-date!
#        | Downloading package pl196x to /root/nltk_data...
#        |   Package pl196x is already up-to-date!
#        | Downloading package porter_test to /root/nltk_data...
#        |   Package porter_test is already up-to-date!
#        | Downloading package ppattach to /root/nltk_data...
#        |   Package ppattach is already up-to-date!
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Package problem_reports is already up-to-date!
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Package product_reviews_1 is already up-to-date!
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Package product_reviews_2 is already up-to-date!
#        | Downloading package propbank to /root/nltk_data...
#        |   Package propbank is already up-to-date!
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Package pros_cons is already up-to-date!
#        | Downloading package ptb to /root/nltk_data...
#        |   Package ptb is already up-to-date!
#        | Downloading package punkt to /root/nltk_data...
#        |   Package punkt is already up-to-date!
#        | Downloading package qc to /root/nltk_data...
#        |   Package qc is already up-to-date!
#        | Downloading package reuters to /root/nltk_data...
#        |   Package reuters is already up-to-date!
#        | Downloading package rslp to /root/nltk_data...
#        |   Package rslp is already up-to-date!
#        | Downloading package rte to /root/nltk_data...
#        |   Package rte is already up-to-date!
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Package sample_grammars is already up-to-date!
#        | Downloading package semcor to /root/nltk_data...
#        |   Package semcor is already up-to-date!
#        | Downloading package senseval to /root/nltk_data...
#        |   Package senseval is already up-to-date!
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Package sentence_polarity is already up-to-date!
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Package sentiwordnet is already up-to-date!
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Package shakespeare is already up-to-date!
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Package sinica_treebank is already up-to-date!
#        | Downloading package smultron to /root/nltk_data...
#        |   Package smultron is already up-to-date!
#        | Downloading package snowball_data to /root/nltk_data...
#        |   Package snowball_data is already up-to-date!
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Package spanish_grammars is already up-to-date!
#        | Downloading package state_union to /root/nltk_data...
#        |   Package state_union is already up-to-date!
#        | Downloading package stopwords to /root/nltk_data...
#        |   Package stopwords is already up-to-date!
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Package subjectivity is already up-to-date!
#        | Downloading package swadesh to /root/nltk_data...
#        |   Package swadesh is already up-to-date!
#        | Downloading package switchboard to /root/nltk_data...
#        |   Package switchboard is already up-to-date!
#        | Downloading package tagsets to /root/nltk_data...
#        |   Package tagsets is already up-to-date!
#        | Downloading package timit to /root/nltk_data...
#        |   Package timit is already up-to-date!
#        | Downloading package toolbox to /root/nltk_data...
#        |   Package toolbox is already up-to-date!
#        | Downloading package treebank to /root/nltk_data...
#        |   Package treebank is already up-to-date!
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Package twitter_samples is already up-to-date!
#        | Downloading package udhr to /root/nltk_data...
#        |   Package udhr is already up-to-date!
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Package udhr2 is already up-to-date!
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Package unicode_samples is already up-to-date!
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Package universal_tagset is already up-to-date!
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        |   Package universal_treebanks_v20 is already up-to-date!
#        | Downloading package vader_lexicon to /root/nltk_data...
#        |   Package vader_lexicon is already up-to-date!
#        | Downloading package verbnet to /root/nltk_data...
#        |   Package verbnet is already up-to-date!
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Package verbnet3 is already up-to-date!
#        | Downloading package webtext to /root/nltk_data...
#        |   Package webtext is already up-to-date!
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Package wmt15_eval is already up-to-date!
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Package word2vec_sample is already up-to-date!
#        | Downloading package wordnet to /root/nltk_data...
#        |   Package wordnet is already up-to-date!
#        | Downloading package wordnet2021 to /root/nltk_data...
#        |   Package wordnet2021 is already up-to-date!
#        | Downloading package wordnet31 to /root/nltk_data...
#        |   Package wordnet31 is already up-to-date!
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Package wordnet_ic is already up-to-date!
#        | Downloading package words to /root/nltk_data...
#        |   Package words is already up-to-date!
#        | Downloading package ycoe to /root/nltk_data...
#        |   Package ycoe is already up-to-date!
#        |
#      Done downloading collection all
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
df['Lower Case'] = df['Review'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['Removal of Punctuation'] = df['Lower Case'].str.replace('[^\w\s]','')
# Out:
# <ipython-input-6-aa3036b0293a>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Removal of Punctuation'] = df['Lower Case'].str.replace('[^\w\s]','')

# %%
import re
df['Removal of Special Characters'] = df['Removal of Punctuation'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x ))
from nltk.corpus import stopwords
nltk.download('stopwords')
stop = stopwords.words('english')
df['Stopwords Removal'] = df['Removal of Punctuation'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from textblob import TextBlob
df['Spelling Correction'] = df['Stopwords Removal'].apply(lambda x: str(TextBlob(x).correct()))
import nltk
nltk.download('punkt')
df['Tokenization'] = df['Spelling Correction'].apply(lambda x: TextBlob(x).words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['After Stemming'] = df['Tokenization'].apply(lambda x: " ".join([st.stem(word) for word in x]))
from textblob import Word
import nltk
nltk.download('wordnet')

df['After Lemmatization'] = df['After Stemming'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df.to_csv('/content/sample_data/reviwes.csv',index=False)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import itertools
import collections
from nltk import ngrams
from nltk.tokenize import word_tokenize

words_sentence = []
for sentence in df['After Lemmatization']:
  words_sentence.append(word_tokenize(sentence))
aftercleaning = [x for x in words_sentence if x != []]
iterations = list(itertools.chain.from_iterable(aftercleaning))

# %%
tri_grams = nltk.trigrams(iterations)
frequency_dist = nltk.FreqDist(tri_grams)
frequency_dist
# Out:
# FreqDist({('taxi', 'driver', 'king'): 6, ('driver', 'king', 'comedi'): 6, ('director', 'told', 'phillip'): 6, ('robert', 'de', 'no'): 6, ('dark', 'knight', 'trilog'): 5, ('perform', 'joaquin', 'phoenix'): 4, ('one', 'best', 'perform'): 4, ('chain', 'modern', 'time'): 3, ('10', 'star', 'review'): 3, ('film', 'joaquin', 'phoenix'): 3, ...})

# %%
from collections import Counter
bi_grams = nltk.bigrams(iterations)
frequency_dist = nltk.FreqDist(bi_grams)
bi_grams_dict = dict(frequency_dist)
for word in bi_grams_dict:
  print( str(word) + ':' + str(bi_grams_dict[word] / iterations.count(word[0])))
# Out:
# Streaming output truncated to the last 5000 lines.
# ('heartbreak', 'inevit'):1.0
# ('inevit', 'becom'):0.3333333333333333
# ('becom', 'clown'):0.06666666666666667
# ('crime', 'know'):0.125
# ('know', 'love'):0.045454545454545456
# ('love', 'although'):0.05555555555555555
# ('although', 'were'):0.5
# ('were', 'never'):0.25
# ('never', 'seen'):0.1
# ('seen', 'like'):0.038461538461538464
# ('like', 'see'):0.016666666666666666
# ('see', 'suffer'):0.02631578947368421
# ('suffer', 'throughout'):0.3333333333333333
# ('throughout', 'movi'):0.2
# ('movi', 'point'):0.005076142131979695
# ('point', 'almost'):0.05555555555555555
# ('almost', 'foot'):0.1111111111111111
# ('foot', 'him'):0.3333333333333333
# ('him', 'becom'):1.0
# ('becom', 'mass'):0.06666666666666667
# ('mass', 'murder'):0.3333333333333333
# ('murder', 'psyco'):1.0
# ('psyco', 'clown'):1.0
# ('clown', 'least'):0.06666666666666667
# ('least', 'make'):0.08333333333333333
# ('feel', 'better'):0.018518518518518517
# ('better', 'happen'):0.05555555555555555
# ('happen', 'wish'):0.07692307692307693
# ('wish', 'could'):0.6666666666666666
# ('could', 'avoid'):0.037037037037037035
# ('avoid', 'e'):0.3333333333333333
# ('e', 'miss'):1.0
# ('miss', 'feel'):0.2
# ('feel', 'care'):0.018518518518518517
# ('care', 'time'):0.14285714285714285
# ('time', 'he'):0.016129032258064516
# ('he', 'joke'):0.14285714285714285
# ('joke', 'wish'):0.0064516129032258064
# ('could', 'help'):0.037037037037037035
# ('help', 'there'):0.16666666666666666
# ('there', 'lot'):0.16666666666666666
# ('lot', 'great'):0.07142857142857142
# ('great', 'nod'):0.02564102564102564
# ('nod', 'greater'):0.2
# ('greater', 'batman'):0.3333333333333333
# ('univers', 'yet'):0.125
# ('yet', 'movi'):0.1111111111111111
# ('movi', 'self'):0.005076142131979695
# ('self', 'contain'):0.3333333333333333
# ('contain', 'charact'):1.0
# ('piec', 'mark'):0.1111111111111111
# ('mark', 'great'):0.6666666666666666
# ('movi', 'act'):0.005076142131979695
# ('act', 'great'):0.023255813953488372
# ('great', 'plot'):0.02564102564102564
# ('plot', 'similar'):0.0625
# ('driver', 'brilliant'):0.043478260869565216
# ('brilliant', 'qualiti'):0.3333333333333333
# ('show', 'dont'):0.047619047619047616
# ('need', 'chi'):0.047619047619047616
# ('chi', 'super'):0.3333333333333333
# ('super', 'power'):0.16666666666666666
# ('power', 'great'):0.14285714285714285
# ('great', 'villain'):0.02564102564102564
# ('villain', 'superhero'):0.05555555555555555
# ('joke', 'everyon'):0.0064516129032258064
# ('everyon', 'get'):0.07142857142857142
# ('movi', 'rise'):0.005076142131979695
# ('rise', 'joke'):0.3333333333333333
# ('joke', '1010'):0.0064516129032258064
# ('1010', 'creativ'):0.14285714285714285
# ('creativ', 'actor'):0.25
# ('actor', 'joaquin'):0.1111111111111111
# ('joaquin', 'creativ'):0.013888888888888888
# ('creativ', 'embodi'):0.25
# ('embodi', 'role'):0.3333333333333333
# ('role', 'joke'):0.15384615384615385
# ('film', 'deserv'):0.012048192771084338
# ('deserv', '10'):0.058823529411764705
# ('10', 'went'):0.14285714285714285
# ('went', 'film'):0.25
# ('film', 'expect'):0.012048192771084338
# ('expect', 'allie'):0.05555555555555555
# ('allie', 'classic'):1.0
# ('classic', 'base'):0.16666666666666666
# ('base', 'review'):0.2
# ('review', 'read'):0.043478260869565216
# ('read', 'end'):0.5
# ('end', 'watch'):0.1
# ('watch', 'decent'):0.022222222222222223
# ('decent', 'film'):0.5
# ('film', 'overal'):0.012048192771084338
# ('overal', 'phoenix'):0.09090909090909091
# ('phoenix', 'outstand'):0.01098901098901099
# ('outstand', 'definit'):0.3333333333333333
# ('definit', 'part'):0.08333333333333333
# ('part', 'feel'):0.1111111111111111
# ('like', 'you'):0.016666666666666666
# ('you', 'seen'):0.2222222222222222
# ('seen', 'trailer'):0.038461538461538464
# ('trailer', 'you'):0.16666666666666666
# ('movi', 'best'):0.005076142131979695
# ('best', 'way'):0.02564102564102564
# ('way', 'describ'):0.02857142857142857
# ('describ', 'film'):0.3333333333333333
# ('film', 'feel'):0.012048192771084338
# ('like', '2'):0.016666666666666666
# ('2', 'hour'):0.3333333333333333
# ('hour', 'version'):0.2
# ('version', 'trailer'):0.3333333333333333
# ('trailer', '2'):0.16666666666666666
# ('hour', 'rel'):0.2
# ('rel', 'common'):0.5
# ('common', 'aunti'):0.25
# ('aunti', 'felt'):1.0
# ('felt', 'lot'):0.1111111111111111
# ('lot', 'longerwhich'):0.07142857142857142
# ('longerwhich', 'isn'):1.0
# ('isn', 'good'):0.15384615384615385
# ('good', 'id'):0.023255813953488372
# ('say', 'much'):0.023255813953488372
# ('much', 'rental'):0.034482758620689655
# ('rental', 'theater'):1.0
# ('theater', 'movi'):0.3333333333333333
# ('movi', 'kind'):0.01015228426395939
# ('kind', 'just'):0.06666666666666667
# ('just', 'batman'):1.0
# ('batman', 'fan'):0.041666666666666664
# ('fan', 'particularli'):0.16666666666666666
# ('particularli', 'fond'):0.25
# ('fond', 'joaquin'):1.0
# ('phoenix', 'movi'):0.02197802197802198
# ('movi', 'truli'):0.005076142131979695
# ('truli', 'except'):0.1
# ('except', 'start'):0.25
# ('start', 'slow'):0.14285714285714285
# ('slow', 'built'):0.1
# ('built', 'viscer'):1.0
# ('viscer', 'satisfi'):0.5
# ('satisfi', 'crescent'):0.25
# ('crescent', 'never'):1.0
# ('would', 'foot'):0.02857142857142857
# ('foot', 'joke'):0.3333333333333333
# ('joke', 'found'):0.0064516129032258064
# ('found', 'throughout'):0.25
# ('joke', 'pain'):0.0064516129032258064
# ('pain', 'palpabl'):0.25
# ('palpabl', 'fill'):1.0
# ('fill', 'oscar'):0.3333333333333333
# ('oscar', 'pool'):0.047619047619047616
# ('pool', 'card'):0.5
# ('card', 'right'):1.0
# ('right', 'is'):0.07142857142857142
# ('is', 'movi'):0.3333333333333333
# ('dark', 'violent'):0.024390243902439025
# ('violent', 'decidedli'):0.06666666666666667
# ('decidedli', 'super'):1.0
# ('super', 'hero'):0.3333333333333333
# ('hero', 'movi'):0.4444444444444444
# ('movi', 'leav'):0.005076142131979695
# ('leav', 'kiss'):0.125
# ('kiss', 'home'):0.3333333333333333
# ('home', 'everyon'):0.25
# ('everyon', 'riot'):0.07142857142857142
# ('riot', 'violent'):0.25
# ('violent', 'actor'):0.06666666666666667
# ('actor', 'skill'):0.05555555555555555
# ('skill', 'isn'):0.3333333333333333
# ('isn', 'great'):0.07692307692307693
# ('great', 'laugh'):0.02564102564102564
# ('laugh', 'anyon'):0.09090909090909091
# ('anyon', 'joke'):0.16666666666666666
# ('joke', 'nomin'):0.0064516129032258064
# ('nomin', 'academi'):0.125
# ('academi', 'award'):1.0
# ('award', 'joke'):0.16666666666666666
# ('joke', 'noncanon'):0.0064516129032258064
# ('noncanon', 'origin'):1.0
# ('stori', 'joke'):0.03125
# ('phoenix', 'play'):0.03296703296703297
# ('play', 'deepli'):0.07142857142857142
# ('deepli', 'disturb'):0.42857142857142855
# ('man', 'name'):0.041666666666666664
# ('fleck', 'experi'):0.034482758620689655
# ('experi', 'seri'):0.125
# ('seri', 'trauma'):0.25
# ('trauma', 'turn'):1.0
# ('turn', 'notori'):0.16666666666666666
# ('notori', 'supervillain'):1.0
# ('supervillain', 'phoenix'):0.5
# ('phoenix', 'terrif'):0.01098901098901099
# ('terrif', 'agon'):1.0
# ('agon', 'lower'):1.0
# ('lower', 'compulsivelaught'):1.0
# ('compulsivelaught', 'condit'):1.0
# ('condit', 'he'):0.125
# ('he', 'weird'):0.14285714285714285
# ('weird', 'creep'):1.0
# ('creep', 'full'):0.5
# ('full', 'angri'):0.14285714285714285
# ('angri', 'anger'):0.25
# ('anger', 'selfloath'):0.3333333333333333
# ('selfloath', 'everyoneelseloath'):1.0
# ('everyoneelseloath', 'first'):1.0
# ('first', 'half'):0.058823529411764705
# ('half', 'hour'):0.3333333333333333
# ('hour', 'simpli'):0.2
# ('simpli', 'grind'):0.3333333333333333
# ('grind', 'agonizingli'):1.0
# ('agonizingli', 'slow'):1.0
# ('slow', 'move'):0.1
# ('move', 'portray'):0.023809523809523808
# ('portray', 'arthur'):0.11764705882352941
# ('arthur', 'life'):0.017857142857142856
# ('life', 'there'):0.08333333333333333
# ('there', 'moment'):0.08333333333333333
# ('moment', 'stun'):0.1111111111111111
# ('stun', 'electrifi'):0.2
# ('electrifi', 'violenc'):1.0
# ('violenc', 'everyth'):0.05555555555555555
# ('everyth', 'get'):0.1
# ('get', 'tediou'):0.017857142857142856
# ('tediou', 'joke'):1.0
# ('joke', 'supervillain'):0.0064516129032258064
# ('supervillain', 'movi'):0.5
# ('movi', 'art'):0.005076142131979695
# ('art', 'charact'):0.1
# ('studi', 'like'):0.2222222222222222
# ('like', 'might'):0.016666666666666666
# ('might', 'appeal'):0.0625
# ('appeal', 'there'):0.5
# ('there', 'superfici'):0.08333333333333333
# ('superfici', 'arthur'):1.0
# ('arthur', 'deepli'):0.017857142857142856
# ('disturb', 'live'):0.05263157894736842
# ('live', 'citi'):0.09090909090909091
# ('citi', 'societi'):0.06666666666666667
# ('societi', 'raven'):0.02857142857142857
# ('raven', 'increasingli'):1.0
# ('increasingli', 'disfranchis'):1.0
# ('disfranchis', 'script'):1.0
# ('script', 'director'):0.16666666666666666
# ('director', 'dont'):0.06666666666666667
# ('dont', 'realli'):0.03225806451612903
# ('realli', 'seem'):0.05714285714285714
# ('seem', 'anyth'):0.05263157894736842
# ('anyth', 'say'):0.18181818181818182
# ('ill', 'inequ'):0.037037037037037035
# ('inequ', 'injustic'):0.3333333333333333
# ('injustic', 'run'):0.5
# ('run', 'film'):0.16666666666666666
# ('film', 'director'):0.006024096385542169
# ('phillip', 'critic'):0.027777777777777776
# ('critic', 'woke'):0.1
# ('woke', 'cultur'):1.0
# ('cultur', 'far'):0.25
# ('far', 'left'):0.23809523809523808
# ('left', 'perhap'):0.08333333333333333
# ('perhap', 'that'):0.3333333333333333
# ('that', 'part'):0.0625
# ('part', 'problem'):0.1111111111111111
# ('problem', 'woke'):0.1
# ('cultur', 'say'):0.25
# ('say', 'need'):0.06976744186046512
# ('need', 'think'):0.047619047619047616
# ('think', 'thing'):0.02564102564102564
# ('thing', 'deepli'):0.045454545454545456
# ('deepli', 'phillip'):0.14285714285714285
# ('phillip', 'realli'):0.027777777777777776
# ('realli', 'realli'):0.02857142857142857
# ('seem', 'loath'):0.05263157894736842
# ('loath', 'delv'):1.0
# ('delv', 'mean'):0.5
# ('mean', 'mental'):0.058823529411764705
# ('unstabl', 'poor'):0.16666666666666666
# ('poor', 'greater'):0.25
# ('greater', 'societi'):0.3333333333333333
# ('societi', 'sen'):0.02857142857142857
# ('sen', 'he'):0.2
# ('he', 'concern'):0.14285714285714285
# ('concern', 'effect'):1.0
# ('effect', 'arthur'):0.25
# ('arthur', 'arthur'):0.017857142857142856
# ('arthur', 'also'):0.017857142857142856
# ('also', 'concern'):0.037037037037037035
# ('arthur', 'result'):0.017857142857142856
# ('result', 'film'):0.25
# ('film', 'seem'):0.006024096385542169
# ('seem', 'accept'):0.05263157894736842
# ('accept', 'arthur'):1.0
# ('arthur', 'victim'):0.017857142857142856
# ('victim', 'unjust'):0.3333333333333333
# ('unjust', 'societi'):0.5
# ('societi', 'never'):0.02857142857142857
# ('never', 'realli'):0.05
# ('realli', 'consid'):0.02857142857142857
# ('consid', 'societi'):0.125
# ('societi', 'unjust'):0.02857142857142857
# ('unjust', 'much'):0.5
# ('much', 'arthur'):0.034482758620689655
# ('arthur', 'problem'):0.017857142857142856
# ('problem', 'might'):0.1
# ('might', 'result'):0.0625
# ('result', 'narcissist'):0.25
# ('narcissist', 'self'):1.0
# ('self', 'piti'):0.3333333333333333
# ('piti', 'main'):0.5
# ('main', 'problem'):0.14285714285714285
# ('problem', 'movi'):0.1
# ('movi', 'slowmov'):0.005076142131979695
# ('slowmov', 'dull'):1.0
# ('dull', 'far'):0.5
# ('far', 'often'):0.047619047619047616
# ('often', 'wouldn'):0.16666666666666666
# ('wouldn', 'recommend'):0.5
# ('recommend', 'film'):0.6666666666666666
# ('film', 'surpass'):0.006024096385542169
# ('surpass', 'film'):1.0
# ('film', 'portray'):0.006024096385542169
# ('portray', 'slow'):0.058823529411764705
# ('slow', 'descent'):0.2
# ('mad', 'caus'):0.09090909090909091
# ('caus', 'biolog'):0.125
# ('biolog', 'psycholog'):0.5
# ('psycholog', 'social'):0.1
# ('social', 'familiar'):0.125
# ('familiar', 'factor'):0.25
# ('factor', 'also'):1.0
# ('also', 'highlight'):0.037037037037037035
# ('highlight', 'decay'):1.0
# ('decay', 'n'):0.5
# ('n', 'broken'):0.2
# ('broken', 'system'):0.16666666666666666
# ('system', 'n'):0.08333333333333333
# ('n', 'societi'):0.2
# ('societi', 'auster'):0.02857142857142857
# ('auster', 'film'):1.0
# ('film', 'dark'):0.018072289156626505
# ('dark', 'amaz'):0.024390243902439025
# ('amaz', 'cinematographi'):0.06666666666666667
# ('cinematographi', 'n'):0.037037037037037035
# ('n', 'year'):0.2
# ('year', 'best'):0.041666666666666664
# ('perform', 'phoenix'):0.03773584905660377
# ('phoenix', 'surrealist'):0.01098901098901099
# ('surrealist', 'feel'):1.0
# ('feel', 'n'):0.018518518518518517
# ('n', 'fact'):0.2
# ('fact', 'solid'):0.07142857142857142
# ('solid', 'non'):1.0
# ('non', 'horror'):0.5
# ('horror', 'film'):0.375
# ('film', 'terrifi'):0.006024096385542169
# ('terrifi', 'n'):0.3333333333333333
# ('n', 'poignant'):0.2
# ('poignant', 'one'):1.0
# ('one', 'prescreen'):0.015151515151515152
# ('prescreen', 'citi'):1.0
# ('citi', 'taken'):0.06666666666666667
# ('taken', 'review'):0.3333333333333333
# ('review', 'titl'):0.043478260869565216
# ('titl', 'give'):0.2
# ('give', 'torn'):0.038461538461538464
# ('torn', 'ye'):1.0
# ('ye', 'joaquin'):0.16666666666666666
# ('phoenix', 'alway'):0.01098901098901099
# ('alway', 'verit'):0.125
# ('verit', 'action'):1.0
# ('action', 'talent'):0.0625
# ('talent', 'wast'):0.2
# ('wast', 'role'):0.16666666666666666
# ('role', 'ye'):0.07692307692307693
# ('ye', 'phoenix'):0.16666666666666666
# ('portray', 'charact'):0.11764705882352941
# ('charact', 'riot'):0.015625
# ('riot', 'ye'):0.25
# ('ye', 'stori'):0.16666666666666666
# ('stori', 'grip'):0.03125
# ('grip', 'also'):0.3333333333333333
# ('also', 'necessari'):0.037037037037037035
# ('necessari', 'especi'):1.0
# ('especi', 'today'):0.16666666666666666
# ('today', 'seem'):0.2
# ('seem', 'mental'):0.05263157894736842
# ('ill', 'run'):0.037037037037037035
# ('run', 'rampart'):0.16666666666666666
# ('rampart', 'ye'):0.5
# ('ye', 'tone'):0.16666666666666666
# ('tone', 'magnific'):0.2
# ('magnific', 'set'):1.0
# ('set', 'within'):0.05555555555555555
# ('within', 'cinemat'):0.16666666666666666
# ('cinemat', 'art'):0.14285714285714285
# ('art', 'direct'):0.1
# ('direct', 'problem'):0.07142857142857142
# ('problem', 'way'):0.1
# ('way', 'tie'):0.02857142857142857
# ('univers', 'particularli'):0.125
# ('particularli', 'common'):0.25
# ('common', 'differenti'):0.25
# ('differenti', 'joke'):1.0
# ('joke', 'past'):0.0064516129032258064
# ('past', 'still'):0.2
# ('still', 'problem'):0.1111111111111111
# ('problem', 'make'):0.1
# ('make', 'two'):0.018867924528301886
# ('two', 'world'):0.5
# ('world', 'merg'):0.05263157894736842
# ('merg', 'quit'):1.0
# ('quit', 'reli'):0.0625
# ('reli', 'critic'):0.5
# ('critic', 'review'):0.1
# ('review', 'year'):0.043478260869565216
# ('year', 'ago'):0.08333333333333333
# ('ago', 'notic'):0.3333333333333333
# ('notic', 'movi'):0.16666666666666666
# ('movi', 'critic'):0.005076142131979695
# ('critic', 'rate'):0.1
# ('rate', 'low'):0.14285714285714285
# ('low', 'viewer'):0.25
# ('viewer', 'rate'):0.1111111111111111
# ('rate', 'high'):0.14285714285714285
# ('high', 'said'):0.2
# ('said', 'point'):0.25
# ('point', 'critic'):0.05555555555555555
# ('critic', 'movi'):0.1
# ('movi', 'oh'):0.005076142131979695
# ('oh', 'wrong'):0.3333333333333333
# ('wrong', 'went'):0.2
# ('went', 'saw'):0.25
# ('saw', 'tone'):0.3333333333333333
# ('tone', 'mon'):0.2
# ('mon', 'went'):0.25
# ('went', 'skeptic'):0.25
# ('skeptic', 'w'):0.5
# ('w', 'low'):1.0
# ('low', 'expect'):0.25
# ('expect', 'knew'):0.05555555555555555
# ('knew', 'expect'):0.5
# ('typic', 'super'):0.25
# ('got', 'masterpiec'):0.25
# ('masterpiec', 'went'):0.043478260869565216
# ('went', 'expect'):0.25
# ('expect', 'sheer'):0.05555555555555555
# ('sheer', 'boredom'):1.0
# ('boredom', 'instead'):1.0
# ('instead', 'edg'):0.2
# ('edg', 'seat'):0.5
# ('seat', 'whole'):0.2
# ('whole', 'time'):0.125
# ('time', 'action'):0.016129032258064516
# ('action', 'edg'):0.0625
# ('seat', 'fear'):0.2
# ('fear', 'may'):0.3333333333333333
# ('may', 'say'):0.1
# ('say', 'next'):0.023255813953488372
# ('next', 'edg'):0.25
# ('seat', 'see'):0.2
# ('see', 'charact'):0.02631578947368421
# ('charact', 'evolv'):0.015625
# ('evolv', 'know'):1.0
# ('know', '1'):0.045454545454545456
# ('1', 'villain'):0.5
# ('villain', 'batman'):0.05555555555555555
# ('batman', 'beyond'):0.041666666666666664
# ('beyond', 'geniu'):1.0
# ('geniu', 'joaquin'):0.3333333333333333
# ('phoenix', 'true'):0.01098901098901099
# ('true', 'master'):0.14285714285714285
# ('master', 'perfect'):0.25
# ('perfect', 'art'):0.09090909090909091
# ('art', 'consum'):0.1
# ('consum', 'charact'):1.0
# ('charact', 'may'):0.015625
# ('may', 'place'):0.1
# ('place', 'dont'):0.125
# ('dont', 'care'):0.03225806451612903
# ('care', 'movi'):0.14285714285714285
# ('movi', 'stori'):0.01015228426395939
# ('direct', 'effect'):0.07142857142857142
# ('effect', 'everyon'):0.125
# ('everyon', 'brought'):0.07142857142857142
# ('brought', 'game'):1.0
# ('game', 'up'):0.3333333333333333
# ('up', 'definit'):1.0
# ('definit', 'deserv'):0.08333333333333333
# ('deserv', 'nod'):0.058823529411764705
# ('nod', 'win'):0.2
# ('win', 'role'):0.125
# ('role', 'comparison'):0.07692307692307693
# ('comparison', 'jack'):0.2
# ('jack', 'nicholson'):1.0
# ('nicholson', 'heath'):0.6666666666666666
# ('ledger', 'actor'):0.058823529411764705
# ('actor', 'took'):0.05555555555555555
# ('took', 'charact'):0.3333333333333333
# ('charact', 'differ'):0.015625
# ('differ', 'level'):0.058823529411764705
# ('level', 'differ'):0.2
# ('differ', 'stori'):0.058823529411764705
# ('stori', 'point'):0.03125
# ('point', 'differ'):0.05555555555555555
# ('differ', 'point'):0.058823529411764705
# ('point', 'time'):0.05555555555555555
# ('time', 'comparison'):0.016129032258064516
# ('comparison', 'would'):0.2
# ('would', 'feasibl'):0.02857142857142857
# ('feasibl', 'fair'):1.0
# ('fair', 'actor'):0.5
# ('actor', 'embrac'):0.05555555555555555
# ('embrac', 'made'):0.5
# ('made', 'come'):0.05555555555555555
# ('come', 'life'):0.05263157894736842
# ('life', 'geniu'):0.041666666666666664
# ('geniu', 'way'):0.3333333333333333
# ('joke', 'liter'):0.0064516129032258064
# ('liter', 'achiev'):0.5
# ('achiev', 'cinemat'):0.25
# ('cinemat', 'histori'):0.14285714285714285
# ('histori', 'there'):0.2
# ('there', 'doubt'):0.08333333333333333
# ('doubt', 'peopl'):0.25
# ('peopl', 'compar'):0.022222222222222223
# ('compar', 'engag'):0.25
# ('engag', 'move'):0.2
# ('move', 'way'):0.023809523809523808
# ('way', 'complet'):0.02857142857142857
# ('complet', 'differ'):0.14285714285714285
# ('differ', 'engag'):0.058823529411764705
# ('engag', 'best'):0.2
# ('best', 'gene'):0.02564102564102564
# ('gene', 'talk'):0.1
# ('talk', 'joke'):0.08333333333333333
# ('joke', 'say'):0.0064516129032258064
# ('say', 'beauti'):0.023255813953488372
# ('beauti', 'present'):0.14285714285714285
# ('present', 'storylin'):0.1
# ('storylin', 'direct'):0.25
# ('screenplay', 'peak'):0.2
# ('peak', 'great'):1.0
# ('great', 'heath'):0.02564102564102564
# ('ledger', 'smile'):0.058823529411764705
# ('smile', 'earth'):0.2
# ('earth', 'take'):1.0
# ('take', 'next'):0.038461538461538464
# ('next', 'ingredi'):0.25
# ('ingredi', 'king'):1.0
# ('comedi', 'requir'):0.06666666666666667
# ('requir', 'dream'):0.3333333333333333
# ('dream', 'dark'):0.16666666666666666
# ('knight', 'taxi'):0.06666666666666667
# ('driver', 'mix'):0.043478260869565216
# ('mix', 'ladi'):0.2
# ('ladi', 'gentleman'):1.0
# ('gentleman', 'joke'):1.0
# ('joke', 'incred'):0.0064516129032258064
# ('incred', 'ride'):0.058823529411764705
# ('ride', 'almost'):0.25
# ('almost', 'motionless'):0.1111111111111111
# ('motionless', 'throughout'):1.0
# ('throughout', 'watch'):0.1
# ('watch', 'awe'):0.022222222222222223
# ('awe', 'perform'):1.0
# ('lifetim', 'transit'):0.3333333333333333
# ('transit', 'troubl'):0.25
# ('troubl', 'man'):0.25
# ('man', 'monster'):0.041666666666666664
# ('monster', 'found'):0.25
# ('found', 'score'):0.25
# ('score', 'directli'):0.038461538461538464
# ('directli', 'drove'):0.5
# ('drove', 'goosebump'):1.0
# ('goosebump', 'cinematographi'):1.0
# ('cinematographi', 'made'):0.037037037037037035
# ('like', 'fli'):0.016666666666666666
# ('fli', 'gothic'):1.0
# ('gothic', 'look'):0.11764705882352941
# ('look', 'arthur'):0.03571428571428571
# ('arthur', 'wast'):0.017857142857142856
# ('wast', 'de'):0.16666666666666666
# ('no', 'gave'):0.1111111111111111
# ('gave', 'nod'):0.2
# ('nod', 'merri'):0.2
# ('merri', 'lewi'):1.0
# ('lewi', 'ignor'):0.5
# ('ignor', 'do'):0.16666666666666666
# ('do', 'ignor'):0.0625
# ('ignor', 'batman'):0.16666666666666666
# ('batman', 'work'):0.041666666666666664
# ('work', 'art'):0.05555555555555555
# ('art', 'right'):0.1
# ('right', 'well'):0.07142857142857142
# ('well', 'play'):0.05555555555555555
# ('play', 'film'):0.07142857142857142
# ('film', 'cours'):0.006024096385542169
# ('cours', 'of'):0.25
# ('of', 'due'):1.0
# ('due', 'dilig'):0.5
# ('dilig', 'howev'):1.0
# ('howev', 'peopl'):0.14285714285714285
# ('peopl', 'blew'):0.022222222222222223
# ('blew', 'that'):1.0
# ('that', 'peopl'):0.0625
# ('peopl', 'day'):0.022222222222222223
# ('day', 'talk'):0.14285714285714285
# ('talk', 'everyth'):0.08333333333333333
# ('everyth', 'that'):0.1
# ('that', 'real'):0.0625
# ('real', 'life'):0.2631578947368421
# ('life', 'good'):0.041666666666666664
# ('good', 'differ'):0.023255813953488372
# ('differ', 'spin'):0.058823529411764705
# ('spin', 'do'):0.5
# ('joke', 'though'):0.0064516129032258064
# ('though', 'outsid'):0.1
# ('outsid', 'do'):0.5
# ('do', 'world'):0.0625
# ('think', 'sinc'):0.02564102564102564
# ('sinc', 'movi'):0.1
# ('movi', 'imagin'):0.005076142131979695
# ('imagin', 'creativ'):0.25
# ('creativ', 'been'):0.25
# ('been', 'lost'):0.3333333333333333
# ('lost', 'chi'):0.3333333333333333
# ('chi', 'take'):0.3333333333333333
# ('take', 'movi'):0.038461538461538464
# ('make', 'huge'):0.018867924528301886
# ('huge', 'deal'):0.3333333333333333
# ('deal', 'each'):0.5
# ('each', 'good'):0.5
# ('good', 'stop'):0.023255813953488372
# ('stop', 'hope'):0.2
# ('hope', 'legendari'):0.05
# ('legendari', 'charact'):0.16666666666666666
# ('charact', 'legendari'):0.015625
# ('legendari', 'perform'):0.5
# ('perform', 'actor'):0.018867924528301886
# ('actor', 'abl'):0.1111111111111111
# ('abl', 'move'):0.14285714285714285
# ('move', 'heath'):0.023809523809523808
# ('ledger', 'perform'):0.058823529411764705
# ('perform', 'movi'):0.018867924528301886
# ('movi', 'total'):0.015228426395939087
# ('total', 'worth'):0.16666666666666666
# ('worth', 'movi'):0.14285714285714285
# ('movi', 'deserv'):0.005076142131979695
# ('oscar', 'showcas'):0.047619047619047616
# ('showcas', 'never'):0.5
# ('seen', 'origin'):0.038461538461538464
# ('origin', 'joke'):0.06666666666666667
# ('joke', 'love'):0.0064516129032258064
# ('love', 'greet'):0.05555555555555555
# ('greet', 'dark'):0.5
# ('dark', 'first'):0.024390243902439025
# ('first', 'thing'):0.058823529411764705
# ('thing', 'know'):0.09090909090909091
# ('know', 'superhero'):0.045454545454545456
# ('movi', 'fact'):0.005076142131979695
# ('fact', 'hero'):0.07142857142857142
# ('movi', 'unless'):0.005076142131979695
# ('unless', 'would'):1.0
# ('like', 'appli'):0.016666666666666666
# ('appli', 'label'):0.5
# ('label', 'singl'):1.0
# ('singl', 'mon'):0.3333333333333333
# ('mon', 'live'):0.25
# ('live', 'hall'):0.09090909090909091
# ('hall', 'arthur'):0.5
# ('fleck', 'mr'):0.034482758620689655
# ('mr', 'fleck'):0.5
# ('fleck', 'live'):0.034482758620689655
# ('live', 'home'):0.09090909090909091
# ('home', 'invalid'):0.25
# ('invalid', 'mother'):1.0
# ('mother', 'wrung'):0.2
# ('wrung', 'renown'):1.0
# ('renown', 'apart'):1.0
# ('apart', 'work'):0.3333333333333333
# ('work', 'clownforhir'):0.05555555555555555
# ('clownforhir', 'dream'):1.0
# ('dream', 'becom'):0.3333333333333333
# ('becom', 'stand'):0.13333333333333333
# ('stand', 'comedian'):0.25
# ('comedian', 'depend'):0.3333333333333333
# ('depend', 'social'):0.5
# ('servic', 'suppli'):0.2
# ('suppli', '7'):1.0
# ('7', 'medit'):1.0
# ('medit', 'take'):0.25
# ('take', 'sinc'):0.038461538461538464
# ('sinc', 'releas'):0.1
# ('releas', 'abraham'):0.25
# ('abraham', 'state'):1.0
# ('state', 'hospit'):0.3333333333333333
# ('hospit', 'bleak'):1.0
# ('bleak', 'exist'):0.25
# ('exist', 'bleak'):0.14285714285714285
# ('bleak', 'time'):0.25
# ('time', 'bleak'):0.016129032258064516
# ('bleak', 'citi'):0.25
# ('citi', 'gothic'):0.06666666666666667
# ('gothic', 'midst'):0.058823529411764705
# ('midst', 'garag'):0.5
# ('garag', 'worker'):0.25
# ('worker', 'strike'):0.5
# ('strike', 'super'):0.5
# ('super', 'rat'):0.16666666666666666
# ('rat', 'happi'):0.3333333333333333
# ('happi', 'polit'):0.25
# ('polit', 'upheav'):0.25
# ('upheav', 'grow'):1.0
# ('grow', 'chasm'):0.3333333333333333
# ('chasm', 'class'):1.0
# ('class', 'get'):0.09090909090909091
# ('get', 'wors'):0.017857142857142856
# ('wors', 'arthur'):0.2
# ('arthur', 'second'):0.017857142857142856
# ('second', 'thing'):0.3333333333333333
# ('know', 'standalon'):0.045454545454545456
# ('standalon', 'joke'):0.25
# ('film', 'one'):0.012048192771084338
# ('one', 'mostli'):0.015151515151515152
# ('mostli', 'unrel'):1.0
# ('unrel', 'connect'):1.0
# ('connect', 'previou'):0.25
# ('previou', 'project'):0.5
# ('project', 'fear'):1.0
# ('fear', 'colour'):0.3333333333333333
# ('colour', 'clown'):1.0
# ('princ', 'charact'):0.3333333333333333
# ('charact', 'play'):0.015625
# ('play', 'voic'):0.07142857142857142
# ('voic', 'memor'):0.3333333333333333
# ('memor', 'actor'):0.25
# ('actor', 'caesar'):0.05555555555555555
# ('caesar', 'robert'):1.0
# ('robert', 'jack'):0.14285714285714285
# ('ledger', 'mark'):0.058823529411764705
# ('mark', 'famili'):0.3333333333333333
# ('famili', 'dare'):0.5
# ('dare', 'let'):0.3333333333333333
# ('let', 'even'):0.16666666666666666
# ('even', 'each'):0.03125
# ('each', 'galifianaki'):0.5
# ('galifianaki', 'director'):1.0
# ('phillip', 'wrote'):0.027777777777777776
# ('wrote', 'script'):0.5
# ('script', 'scott'):0.16666666666666666
# ('scott', 'silver'):1.0
# ('silver', 'best'):0.5
# ('best', 'known'):0.02564102564102564
# ('known', 'extrem'):0.2
# ('extrem', 'remedi'):0.3333333333333333
# ('remedi', 'hanov'):1.0
# ('hanov', 'franchis'):0.2
# ('franchis', 'old'):0.25
# ('old', 'school'):0.6666666666666666
# ('school', 'he'):0.3333333333333333
# ('he', 'bit'):0.14285714285714285
# ('bit', 'outsid'):0.125
# ('outsid', 'usual'):0.5
# ('usual', 'wheelhous'):0.1111111111111111
# ('wheelhous', 'phillip'):1.0
# ('phillip', 'silver'):0.027777777777777776
# ('silver', 'seem'):0.5
# ('seem', 'embrac'):0.05263157894736842
# ('embrac', 'histori'):0.5
# ('histori', 'charact'):0.2
# ('charact', 'also'):0.015625
# ('also', 'look'):0.037037037037037035
# ('look', 'textur'):0.03571428571428571
# ('textur', 'tone'):1.0
# ('tone', 'filmmak'):0.2
# ('filmmak', 'earlier'):0.5
# ('earlier', 'era'):1.0
# ('era', 'gritti'):1.0
# ('gritti', 'outcast'):0.14285714285714285
# ('outcast', 'feel'):0.3333333333333333
# ('feel', 'scorces'):0.018518518518518517
# ('scorces', 'taxi'):1.0
# ('comedi', 'present'):0.06666666666666667
# ('present', 'numer'):0.1
# ('numer', 'tribut'):0.5
# ('tribut', 'familiar'):0.3333333333333333
# ('familiar', 'joke'):0.25
# ('moment', 'day'):0.1111111111111111
# ('day', 'gone'):0.14285714285714285
# ('gone', 'three'):0.3333333333333333
# ('three', 'time'):0.14285714285714285
# ('time', 'oscar'):0.016129032258064516
# ('oscar', 'nomine'):0.047619047619047616
# ('nomine', 'joaquin'):1.0
# ('play', 'arthur'):0.07142857142857142
# ('fleck', 'deliv'):0.034482758620689655
# ('deliv', 'arthur'):0.125
# ('arthur', 'slow'):0.017857142857142856
# ('mad', 'shall'):0.09090909090909091
# ('shall', 'say'):1.0
# ('say', 'descent'):0.023255813953488372
# ('descent', 'clear'):0.16666666666666666
# ('clear', 'begin'):0.2
# ('begin', 'arthur'):0.16666666666666666
# ('arthur', 'view'):0.017857142857142856
# ('view', 'ignor'):0.14285714285714285
# ('ignor', 'societi'):0.16666666666666666
# ('societi', 'want'):0.02857142857142857
# ('want', 'bring'):0.038461538461538464
# ('bring', 'joy'):0.08333333333333333
# ('joy', 'laughter'):1.0
# ('laughter', 'other'):0.14285714285714285
# ('other', 'notic'):0.1111111111111111
# ('notic', 'daydream'):0.16666666666666666
# ('daydream', 'vision'):1.0
# ('vision', 'better'):0.5
# ('better', 'world'):0.05555555555555555
# ('world', 'send'):0.05263157894736842
# ('send', 'strong'):0.5
# ('strong', 'messag'):0.3333333333333333
# ('messag', 'phoenix'):0.1111111111111111
# ('phoenix', 'show'):0.01098901098901099
# ('show', 'u'):0.047619047619047616
# ('u', 'full'):0.0625
# ('full', 'commit'):0.14285714285714285
# ('commit', 'role'):0.4
# ('role', 'look'):0.07692307692307693
# ('like', 'lost'):0.016666666666666666
# ('lost', '50'):0.3333333333333333
# ('50', 'pound'):1.0
# ('pound', 'leav'):1.0
# ('leav', 'frame'):0.125
# ('frame', 'content'):0.2
# ('content', 'move'):0.3333333333333333
# ('move', 'danc'):0.023809523809523808
# ('danc', 'manner'):0.16666666666666666
# ('manner', 'unlik'):0.25
# ('unlik', 'were'):0.5
# ('were', 'seen'):0.25
# ('seen', 'fact'):0.038461538461538464
# ('fact', 'tissu'):0.07142857142857142
# ('tissu', 'show'):1.0
# ('show', 'frequent'):0.047619047619047616
# ('frequent', 'danc'):0.3333333333333333
# ('danc', 'move'):0.16666666666666666
# ('move', 'magic'):0.023809523809523808
# ('magic', 'pain'):0.3333333333333333
# ('pain', 'laughter'):0.25
# ('laughter', 'inform'):0.14285714285714285
# ('inform', 'arthur'):1.0
# ('arthur', 'suffer'):0.017857142857142856
# ('suffer', 'pseudobulbar'):0.3333333333333333
# ('pseudobulbar', 'affect'):1.0
# ('affect', 'also'):0.3333333333333333
# ('also', 'known'):0.037037037037037035
# ('known', 'emot'):0.2
# ('emot', 'incontin'):0.07692307692307693
# ('incontin', 'caus'):1.0
# ('caus', 'creep'):0.125
# ('creep', 'laughter'):0.5
# ('laughter', 'pop'):0.14285714285714285
# ('pop', 'inappropri'):0.3333333333333333
# ('inappropri', 'time'):0.5
# ('time', 'cours'):0.016129032258064516
# ('cours', 'comparison'):0.25
# ('comparison', 'heath'):0.2
# ('ledger', 'oscar'):0.058823529411764705
# ('win', 'turn'):0.125
# ('turn', 'dark'):0.16666666666666666
# ('knight', 'inevit'):0.06666666666666667
# ('inevit', 'role'):0.3333333333333333
# ('role', 'film'):0.07692307692307693
# ('film', 'written'):0.006024096385542169
# ('written', 'quit'):0.5
# ('quit', 'differ'):0.0625
# ('differ', 'safe'):0.058823529411764705
# ('safe', 'say'):0.5
# ('say', 'actor'):0.023255813953488372
# ('actor', 'allen'):0.05555555555555555
# ('allen', 'action'):1.0
# ('action', 'sequenc'):0.0625
# ('sequenc', 'special'):0.3333333333333333
# ('special', 'visual'):0.2
# ('visual', 'effect'):0.3333333333333333
# ('effect', 'notic'):0.125
# ('notic', 'absent'):0.16666666666666666
# ('absent', 'violenc'):1.0
# ('violenc', 'sure'):0.05555555555555555
# ('sure', 'shock'):0.047619047619047616
# ('shock', 'one'):0.3333333333333333
# ('one', 'younger'):0.015151515151515152
# ('younger', 'kiss'):1.0
# ('kiss', 'matter'):0.3333333333333333
# ('matter', 'much'):0.25
# ('much', 'enjoy'):0.06896551724137931
# ('enjoy', 'avenu'):0.07692307692307693
# ('avenu', 'wonder'):1.0
# ('wonder', 'woman'):0.125
# ('woman', 'do'):0.2
# ('do', 'marvel'):0.0625
# ('marvel', 'film'):0.5
# ('film', 'gritti'):0.006024096385542169
# ('gritti', 'viscer'):0.14285714285714285
# ('viscer', 'approach'):0.5
# ('approach', 'often'):0.3333333333333333
# ('often', 'tough'):0.16666666666666666
# ('tough', 'watch'):1.0
# ('watch', 'much'):0.022222222222222223
# ('much', 'charact'):0.034482758620689655
# ('studi', 'mental'):0.1111111111111111
# ('ill', 'costum'):0.037037037037037035
# ('costum', 'drama'):0.2
# ('drama', 'although'):0.1
# ('although', 'arthur'):0.5
# ('arthur', 'cloth'):0.017857142857142856
# ('cloth', 'make'):1.0
# ('make', 'front'):0.018867924528301886
# ('front', 'center'):0.3333333333333333
# ('center', 'arthur'):1.0
# ('arthur', 'state'):0.017857142857142856
# ('state', 'noth'):0.3333333333333333
# ('noth', 'bad'):0.125
# ('bad', 'thought'):0.05263157894736842
# ('thought', 'believ'):0.058823529411764705
# ('believ', 'sympathet'):0.09090909090909091
# ('sympathet', 'back'):0.3333333333333333
# ('back', 'stori'):0.1111111111111111
# ('stori', 'explain'):0.03125
# ('explain', 'great'):0.5
# ('great', 'deal'):0.02564102564102564
# ('deal', 'like'):0.5
# ('like', 'prove'):0.016666666666666666
# ('prove', 'quit'):0.5
# ('quit', 'controversi'):0.0625
# ('controversi', 'phoenix'):0.2
# ('phoenix', 'domin'):0.01098901098901099
# ('domin', 'film'):1.0
# ('film', 'support'):0.006024096385542169
# ('support', 'work'):0.125
# ('work', 'provid'):0.05555555555555555
# ('provid', 'robert'):0.3333333333333333
# ('no', 'murray'):0.1111111111111111
# ('franklin', 'to'):0.2
# ('to', 'talk'):0.3333333333333333
# ('host', 'johnni'):0.25
# ('johnni', 'carson'):1.0
# ('carson', 'mode'):1.0
# ('mode', 'gaze'):1.0
# ('been', 'deadpool'):0.3333333333333333
# ('deadpool', '2'):0.5
# ('2', 'singl'):0.16666666666666666
# ('mon', 'neighbor'):0.25
# ('demand', 'franc'):0.25
# ('convoy', 'penni'):0.25
# ('fleck', 'arthur'):0.034482758620689655
# ('arthur', 'mother'):0.017857142857142856
# ('mother', 'brest'):0.2
# ('brest', 'cullen'):1.0
# ('cullen', 'sympathet'):1.0
# ('sympathet', 'thoma'):0.3333333333333333
# ('wayn', 'she'):0.07692307692307693
# ('she', 'brigham'):1.0
# ('brigham', 'bill'):1.0
# ('bill', 'camp'):1.0
# ('camp', 'polic'):1.0
# ('polic', 'detect'):0.5
# ('detect', 'ill'):1.0
# ('ill', 'hesitantli'):0.037037037037037035
# ('hesitantli', 'mention'):1.0
# ('mention', 'date'):0.25
# ('date', 'pereiraolson'):1.0
# ('pereiraolson', 'make'):1.0
# ('make', 'coupl'):0.018867924528301886
# ('coupl', 'brief'):0.25
# ('brief', 'appear'):1.0
# ('appear', 'adolesc'):0.14285714285714285
# ('adolesc', 'bruce'):1.0
# ('bruce', 'wayn'):1.0
# ('wayn', 'fun'):0.07692307692307693
# ('fun', 'get'):0.25
# ('get', 'shot'):0.017857142857142856
# ('shot', 'young'):0.1111111111111111
# ('young', 'man'):0.3333333333333333
# ('man', 'hope'):0.041666666666666664
# ('hope', 'battl'):0.05
# ('battl', 'skill'):0.5
# ('skill', 'use'):0.3333333333333333
# ('use', 'later'):0.09090909090909091
# ('later', 'life'):0.25
# ('life', 'dont'):0.041666666666666664
# ('dont', 'expect'):0.06451612903225806
# ('expect', 'real'):0.05555555555555555
# ('real', 'batman'):0.05263157894736842
# ('refer', 'director'):0.16666666666666666
# ('director', 'phillip'):0.06666666666666667
# ('phillip', 'deliv'):0.027777777777777776
# ('deliv', 'film'):0.125
# ('film', 'look'):0.006024096385542169
# ('look', 'feel'):0.03571428571428571
# ('feel', 'sound'):0.018518518518518517
# ('sound', 'much'):0.1111111111111111
# ('much', 'differ'):0.034482758620689655
# ('differ', 'comic'):0.058823529411764705
# ('book', 'move'):0.07142857142857142
# ('move', 'cinematograph'):0.023809523809523808
# ('cinematograph', 'lawrenc'):1.0
# ('lawrenc', 'her'):1.0
# ('her', 'frequent'):0.5
# ('frequent', 'phillip'):0.3333333333333333
# ('phillip', 'collabor'):0.027777777777777776
# ('collabor', '3'):1.0
# ('3', 'hanov'):0.5
# ('move', 'dark'):0.023809523809523808
# ('dark', 'look'):0.024390243902439025
# ('look', 'gritti'):0.03571428571428571
# ('gritti', 'feel'):0.14285714285714285
# ('feel', 'present'):0.018518518518518517
# ('present', 'everi'):0.1
# ('everi', 'shot'):0.07142857142857142
# ('shot', 'holder'):0.1111111111111111
# ('holder', 'guonadottir'):0.3333333333333333
# ('guonadottir', 'year'):1.0
# ('year', 'emma'):0.041666666666666664
# ('emma', 'winner'):1.0
# ('winner', 'chernobyl'):1.0
# ('chernobyl', 'serv'):1.0
# ('serv', 'forebod'):0.5
# ('forebod', 'score'):1.0
# ('score', 'one'):0.038461538461538464
# ('one', 'never'):0.015151515151515152
# ('never', 'overwhelm'):0.05
# ('overwhelm', 'one'):0.5
# ('one', 'contrast'):0.015151515151515152
# ('contrast', 'perfectli'):1.0
# ('perfectli', 'tradit'):0.14285714285714285
# ('tradit', 'song'):1.0
# ('song', 'util'):0.3333333333333333
# ('util', 'throughout'):0.3333333333333333
# ('throughout', 'stephen'):0.1
# ('stephen', 'sondheim'):1.0
# ('sondheim', 'send'):1.0
# ('send', 'clown'):0.5
# ('clown', 'jimmi'):0.06666666666666667
# ('jimmi', 'urat'):1.0
# ('urat', 'sing'):1.0
# ('sing', 'smile'):1.0
# ('smile', 'dream'):0.2
# ('dream', 'white'):0.16666666666666666
# ('white', 'room'):0.5
# ('room', 'that'):1.0
# ('that', 'life'):0.0625
# ('life', 'frank'):0.041666666666666664
# ('frank', 'intra'):1.0
# ('intra', 'mari'):1.0
# ('mari', 'glitter'):1.0
# ('glitter', 'familiar'):0.3333333333333333
# ('familiar', 'rock'):0.25
# ('rock', 'roll'):1.0
# ('roll', 'part'):0.3333333333333333
# ('part', '1'):0.1111111111111111
# ('1', '2'):0.5
# ('2', 'smile'):0.16666666666666666
# ('smile', 'song'):0.2
# ('song', 'especi'):0.3333333333333333
# ('especi', 'relev'):0.16666666666666666
# ('relev', 'origin'):0.3333333333333333
# ('origin', 'trace'):0.06666666666666667
# ('trace', 'charli'):0.5
# ('charli', 'chain'):0.5
# ('time', 'silent'):0.016129032258064516
# ('silent', 'movi'):1.0
# ('movi', 'classic'):0.005076142131979695
# ('classic', 'featur'):0.16666666666666666
# ('featur', 'film'):0.4
# ('film', 'phillip'):0.012048192771084338
# ('phillip', 'even'):0.027777777777777776
# ('even', 'use'):0.03125
# ('use', 'saul'):0.09090909090909091
# ('saul', 'bass'):1.0
# ('bass', 'design'):1.0
# ('design', 'warn'):0.14285714285714285
# ('warn', 'brow'):0.5
# ('brow', 'log'):1.0
# ('log', 'open'):1.0
# ('open', 'credit'):0.2
# ('credit', 'make'):0.25
# ('make', 'sure'):0.018867924528301886
# ('sure', 'understand'):0.047619047619047616
# ('understand', 'time'):0.18181818181818182
# ('time', 'period'):0.016129032258064516
# ('period', 'cell'):0.5
# ('cell', 'phone'):1.0
# ('phone', 'etc'):1.0
# ('etc', 'film'):1.0
# ('film', 'trace'):0.006024096385542169
# ('trace', 'arthur'):0.5
# ('arthur', 'slide'):0.017857142857142856
# ('slide', 'crime'):0.3333333333333333
# ('crime', 'transit'):0.125
# ('transit', 'want'):0.25
# ('want', 'seek'):0.038461538461538464
# ('seek', 'one'):1.0
# ('one', 'believ'):0.015151515151515152
# ('believ', 'forc'):0.09090909090909091
# ('forc', 'upon'):0.2
# ('upon', 'rise'):0.25
# ('rise', 'savior'):0.3333333333333333
# ('savior', 'work'):1.0
# ('work', 'class'):0.05555555555555555
# ('class', 'secondari'):0.09090909090909091
# ('secondari', 'journey'):1.0
# ('journey', 'chao'):0.5
# ('chao', 'handl'):0.3333333333333333
# ('handl', 'perimet'):0.5
# ('perimet', 'film'):1.0
# ('film', 'prevent'):0.006024096385542169
# ('prevent', 'becom'):1.0
# ('becom', 'super'):0.13333333333333333
# ('super', 'villain'):0.3333333333333333
# ('villain', 'movi'):0.1111111111111111
# ('keep', 'mind'):0.2222222222222222
# ('mind', 'joke'):0.1
# ('joke', 'play'):0.0064516129032258064
# ('play', 'venic'):0.07142857142857142
# ('venic', 'tellurid'):0.3333333333333333
# ('tellurid', 'toronto'):1.0
# ('toronto', 'three'):1.0
# ('three', 'prestigi'):0.14285714285714285
# ('prestigi', 'festiv'):1.0
# ('festiv', 'anoth'):0.5
# ('anoth', 'thing'):0.1111111111111111
# ('thing', 'set'):0.045454545454545456
# ('set', 'apart'):0.05555555555555555
# ('apart', 'other'):0.3333333333333333
# ('other', 'gene'):0.1111111111111111
# ('gene', 'despit'):0.1
# ('despit', '1981'):0.08333333333333333
# ('1981', 'time'):0.5
# ('time', 'stamp'):0.016129032258064516
# ('stamp', 'consist'):1.0
# ('consist', 'antirich'):1.0
# ('antirich', 'messag'):1.0
# ('messag', 'class'):0.1111111111111111
# ('class', 'dispar'):0.09090909090909091
# ('dispar', 'preval'):1.0
# ('preval', 'throughout'):0.3333333333333333
# ('throughout', 'appear'):0.1
# ('appear', 'phillip'):0.14285714285714285
# ('phillip', 'way'):0.027777777777777776
# ('way', 'includ'):0.02857142857142857
# ('includ', 'contemporari'):0.3333333333333333
# ('contemporari', 'theme'):0.3333333333333333
# ('theme', 'decadesold'):0.14285714285714285
# ('decadesold', 'set'):1.0
# ('set', 'cautionari'):0.05555555555555555
# ('cautionari', 'tale'):1.0
# ('tale', 'clown'):0.25
# ('clown', 'left'):0.06666666666666667
# ('behind', 'whether'):0.3333333333333333
# ('whether', 'end'):0.25
# ('end', 'love'):0.1
# ('love', 'hate'):0.1111111111111111
# ('hate', 'joke'):0.125
# ('joke', 'told'):0.0064516129032258064
# ('phillip', 'gritti'):0.027777777777777776
# ('gritti', 'score'):0.14285714285714285
# ('score', 'like'):0.038461538461538464
# ('like', 'take'):0.016666666666666666
# ('take', 'legendari'):0.038461538461538464
# ('legendari', 'do'):0.16666666666666666
# ('comic', 'villain'):0.038461538461538464
# ('villain', 'there'):0.05555555555555555
# ('there', 'deni'):0.08333333333333333
# ('deni', 'cinemat'):1.0
# ('cinemat', 'comic'):0.14285714285714285
# ('book', 'adapt'):0.07142857142857142
# ('adapt', 'landscap'):0.25
# ('landscap', 'chang'):0.5
# ('chang', 'forev'):0.14285714285714285
# ('forev', 'woman'):0.5
# ('woman', 'chang'):0.2
# ('chang', 'expect'):0.14285714285714285
# ('expect', 'comic'):0.05555555555555555
# ('book', 'film'):0.14285714285714285
# ('joke', 'examin'):0.0064516129032258064
# ('examin', 'birth'):1.0
# ('birth', 'nefari'):0.5
# ('nefari', 'villain'):1.0
# ('villain', 'hellbent'):0.05555555555555555
# ('hellbent', 'chao'):1.0
# ('chao', 'anarchi'):0.3333333333333333
# ('anarchi', 'unlik'):1.0
# ('unlik', 'anyth'):0.5
# ('anyth', 'were'):0.09090909090909091
# ('were', 'ever'):0.25
# ('seen', 'strip'):0.038461538461538464
# ('strip', 'well'):0.5
# ('known', 'charact'):0.2
# ('charact', 'back'):0.015625
# ('back', 'bare'):0.1111111111111111
# ('bare', 'basi'):0.2
# ('basi', 'introduc'):1.0
# ('introduc', 'sad'):1.0
# ('sad', 'life'):0.125
# ('life', 'misunderstood'):0.041666666666666664
# ('misunderstood', 'unmov'):1.0
# ('unmov', 'arthur'):1.0
# ('fleck', 'share'):0.034482758620689655
# ('share', 'common'):1.0
# ('common', 'drama'):0.25
# ('drama', 'taxi'):0.1
# ('driver', 'servic'):0.043478260869565216
# ('servic', 'rather'):0.2
# ('rather', 'comic'):0.14285714285714285
# ('book', 'cousin'):0.07142857142857142
# ('cousin', 'phillip'):1.0
# ('phillip', 'mindbogglingli'):0.027777777777777776
# ('mindbogglingli', 'good'):1.0
# ('good', 'lead'):0.023255813953488372
# ('lead', 'man'):0.25
# ('man', 'joaquin'):0.041666666666666664
# ('phoenix', 'take'):0.01098901098901099
# ('take', 'u'):0.038461538461538464
# ('u', 'mind'):0.0625
# ('mind', 'broken'):0.1
# ('man', 'tri'):0.125
# ('tri', 'fit'):0.08333333333333333
# ('fit', 'world'):0.2
# ('world', 'doesn'):0.05263157894736842
# ('doesn', 'want'):0.07692307692307693
# ('want', 'open'):0.038461538461538464
# ('open', 'arm'):0.2
# ('arm', 'what'):0.5
# ('what', 'engag'):0.3333333333333333
# ('engag', 'can'):0.2
# ('can', 'look'):0.08333333333333333
# ('away', 'charact'):0.16666666666666666
# ('studi', 'slowli'):0.1111111111111111
# ('slowli', 'sure'):0.3333333333333333
# ('sure', 'descend'):0.047619047619047616
# ('descend', 'dark'):1.0
# ('dark', 'uncomfort'):0.024390243902439025
# ('uncomfort', 'place'):0.25
# ('place', 'befit'):0.125
# ('befit', 'name'):1.0
# ('name', 'reput'):0.2
# ('reput', 'titl'):1.0
# ('titl', 'may'):0.2
# ('may', 'seem'):0.1
# ('seem', 'far'):0.05263157894736842
# ('far', 'earli'):0.047619047619047616
# ('earli', 'call'):0.3333333333333333
# ('call', 'one'):0.125
# ('one', 'confid'):0.015151515151515152
# ('confid', 'say'):0.5
# ('say', 'phoenix'):0.023255813953488372
# ('phoenix', 'full'):0.01098901098901099
# ('full', 'embodi'):0.14285714285714285
# ('embodi', 'fleck'):0.3333333333333333
# ('fleck', 'goe'):0.034482758620689655
# ('goe', 'one'):0.2
# ('one', 'singularli'):0.015151515151515152
# ('singularli', 'impress'):1.0
# ('impress', 'act'):0.3333333333333333
# ('act', 'turn'):0.023255813953488372
# ('turn', 'decad'):0.16666666666666666
# ('decad', 'time'):0.14285714285714285
# ('time', 'similar'):0.016129032258064516
# ('similar', 'de'):0.14285714285714285
# ('no', 'train'):0.1111111111111111
# ('train', 'sickl'):0.6
# ('sickl', 'taxi'):0.3333333333333333
# ('driver', 'daniel'):0.043478260869565216
# ('daniel', 'day'):0.3333333333333333
# ('day', 'lewi'):0.14285714285714285
# ('lewi', 'daniel'):0.5
# ('daniel', 'plainview'):0.3333333333333333
# ('plainview', 'blood'):1.0
# ('blood', 'pace'):0.2
# ('pace', 'achiev'):0.2
# ('achiev', 'sunni'):0.25
# ('sunni', 'dog'):1.0
# ('dog', 'day'):0.5
# ('day', 'afternoon'):0.14285714285714285
# ('afternoon', 'phoenix'):1.0
# ('phoenix', 'command'):0.01098901098901099
# ('command', 'everi'):1.0
# ('everi', 'second'):0.07142857142857142
# ('second', 'screen'):0.3333333333333333
# ('get', 'phillip'):0.017857142857142856
# ('phillip', 'dark'):0.027777777777777776
# ('dark', 'tale'):0.024390243902439025
# ('tale', 'must'):0.25
# ('must', 'sure'):0.16666666666666666
# ('sure', 'biggest'):0.047619047619047616
# ('biggest', 'sure'):0.5
# ('sure', 'fire'):0.047619047619047616
# ('fire', 'bet'):0.3333333333333333
# ('bet', 'oscar'):1.0
# ('oscar', 'could'):0.047619047619047616
# ('could', 'ever'):0.07407407407407407
# ('ever', 'hope'):0.043478260869565216
# ('hope', 'get'):0.1
# ('get', 'way'):0.017857142857142856
# ('way', 'fleck'):0.02857142857142857
# ('fleck', 'appear'):0.034482758620689655
# ('appear', 'physic'):0.14285714285714285
# ('physic', 'simpl'):0.14285714285714285
# ('simpl', 'walk'):0.5
# ('walk', 'slight'):0.25
# ('slight', 'facial'):1.0
# ('facial', 'tick'):0.25
# ('tick', 'right'):1.0
# ('right', 'hunt'):0.07142857142857142
# ('hunt', 'hard'):0.25
# ('hard', 'forget'):0.14285714285714285
# ('forget', 'collect'):0.3333333333333333
# ('collect', 'hunt'):1.0
# ('hunt', 'laugh'):0.25
# ('laugh', 'phoenix'):0.09090909090909091
# ('phoenix', 'appear'):0.01098901098901099
# ('appear', 'virtual'):0.14285714285714285
# ('virtual', 'everi'):1.0
# ('everi', 'scene'):0.07142857142857142
# ('scene', 'joke'):0.05263157894736842
# ('joke', 'never'):0.0064516129032258064
# ('never', 'one'):0.05
# ('one', 'fail'):0.015151515151515152
# ('fail', 'enthral'):0.2
# ('enthral', 'manag'):0.5
# ('manag', 'seemingli'):0.16666666666666666
# ('seemingli', 'imposs'):0.5
# ('imposs', 'allow'):0.25
# ('allow', 'u'):0.16666666666666666
# ('u', 'understand'):0.0625
# ('understand', 'deepli'):0.09090909090909091
# ('deepli', 'flow'):0.14285714285714285
# ('flow', 'deprav'):0.25
# ('deprav', 'creatur'):1.0
# ('creatur', 'creatur'):0.5
# ('creatur', 'begin'):0.5
# ('begin', 'understand'):0.16666666666666666
# ('time', 'even'):0.016129032258064516
# ('even', 'feel'):0.0625
# ('feel', 'sympathi'):0.037037037037037035
# ('sympathi', 'toward'):0.3333333333333333
# ('toward', 'great'):0.14285714285714285
# ('great', 'inclin'):0.02564102564102564
# ('inclin', 'charact'):1.0
# ('charact', 'hard'):0.015625
# ('hard', 'think'):0.14285714285714285
# ('think', 'better'):0.02564102564102564
# ('better', 'way'):0.05555555555555555
# ('joke', 'could'):0.0064516129032258064
# ('could', 'born'):0.037037037037037035
# ('born', 'exist'):0.5
# ('exist', 'bring'):0.14285714285714285
# ('bring', 'flavour'):0.08333333333333333
# ('flavour', 'glanc'):1.0
# ('glanc', 'fleck'):0.5
# ('fleck', 'there'):0.034482758620689655
# ('there', 'point'):0.08333333333333333
# ('point', 'compar'):0.05555555555555555
# ('compar', 'phoenix'):0.25
# ('phoenix', 'heath'):0.01098901098901099
# ('ledger', 'iron'):0.058823529411764705
# ('iron', 'take'):0.1
# ('take', 'face'):0.038461538461538464
# ('face', 'paint'):0.1111111111111111
# ('paint', 'mad'):0.2
# ('mad', 'man'):0.09090909090909091
# ('man', 'take'):0.041666666666666664
# ('take', 'whole'):0.038461538461538464
# ('whole', 'differ'):0.125
# ('differ', 'beast'):0.058823529411764705
# ('beast', 'entir'):0.5
# ('entir', 'good'):0.2
# ('good', 'phoenix'):0.023255813953488372
# ('phoenix', 'would'):0.01098901098901099
# ('would', 'taken'):0.02857142857142857
# ('taken', 'film'):0.3333333333333333
# ('far', 'phillip'):0.047619047619047616
# ('phillip', 'team'):0.027777777777777776
# ('team', 'come'):1.0
# ('come', 'parti'):0.05263157894736842
# ('parti', 'rel'):1.0
# ('rel', 'small'):0.5
# ('small', 'budget'):0.5
# ('budget', 'film'):1.0
# ('film', 'joke'):0.030120481927710843
# ('joke', 'astound'):0.0064516129032258064
# ('astound', 'overal'):0.25
# ('overal', 'qualiti'):0.09090909090909091
# ('qualiti', 'ensur'):0.2
# ('ensur', 'comfort'):1.0
# ('comfort', 'sit'):0.3333333333333333
# ('sit', 'top'):0.3333333333333333
# ('top', 'class'):0.6666666666666666
# ('class', '2019'):0.09090909090909091
# ('2019', 'film'):0.125
# ('film', 'amaz'):0.012048192771084338
# ('amaz', 'think'):0.06666666666666667
# ('think', 'film'):0.07692307692307693
# ('film', 'man'):0.012048192771084338
# ('man', 'gave'):0.041666666666666664
# ('u', 'old'):0.0625
# ('school', 'hanov'):0.3333333333333333
# ('hanov', 'joke'):0.2
# ('joke', 'see'):0.012903225806451613
# ('see', 'phillip'):0.02631578947368421
# ('phillip', 'grow'):0.027777777777777776
# ('grow', 'whole'):0.3333333333333333
# ('whole', 'new'):0.125
# ('new', 'level'):0.07692307692307693
# ('level', 'point'):0.2
# ('point', 'direct'):0.05555555555555555
# ('direct', 'fit'):0.07142857142857142
# ('fit', 'perfectli'):0.2
# ('perfectli', 'lawrenc'):0.14285714285714285
# ('her', 'eyecaptur'):0.5
# ('eyecaptur', 'wa'):1.0
# ('wa', 'like'):0.14285714285714285
# ('like', 'cinematographi'):0.016666666666666666
# ('cinematographi', 'holder'):0.037037037037037035
# ('holder', 'guðnadóttir'):0.6666666666666666
# ('guðnadóttir', 'memor'):0.5
# ('memor', 'score'):0.25
# ('score', 'give'):0.038461538461538464
# ('give', 'joke'):0.038461538461538464
# ('joke', 'epic'):0.0064516129032258064
# ('epic', 'unforgett'):1.0
# ('unforgett', 'cinemat'):0.5
# ('cinemat', 'nerv'):0.14285714285714285
# ('nerv', 'bring'):1.0
# ('bring', 'game'):0.08333333333333333
# ('game', 'match'):0.3333333333333333
# ('match', 'captiv'):0.3333333333333333
# ('captiv', 'lead'):1.0
# ('man', 'first'):0.041666666666666664
# ('first', 'foremost'):0.058823529411764705
# ('foremost', 'believ'):1.0
# ('believ', 'tale'):0.09090909090909091
# ('tale', 'man'):0.25
# ('man', 'push'):0.041666666666666664
# ('push', 'edg'):0.6666666666666666
# ('edg', 'alreadi'):0.125
# ('alreadi', 'enter'):0.14285714285714285
# ('enter', 'limit'):0.5
# ('limit', 'joke'):1.0
# ('joke', 'also'):0.0064516129032258064
# ('also', 'manag'):0.037037037037037035
# ('manag', 'throw'):0.16666666666666666
# ('throw', 'number'):1.0
# ('number', 'surpris'):1.0
# ('surpris', 'narr'):0.25
# ('narr', 'comic'):0.3333333333333333
# ('book', 'throwback'):0.07142857142857142
# ('throwback', 'doubt'):1.0
# ('doubt', 'discus'):0.25
# ('discus', 'adnauseam'):0.5
# ('adnauseam', 'richard'):1.0
# ('richard', 'fan'):1.0
# ('fan', 'natur'):0.16666666666666666
# ('natur', 'tie'):0.5
# ('tie', 'togeth'):0.25
# ('togeth', 'fleck'):0.5
# ('fleck', 'stori'):0.034482758620689655
# ('stori', 'much'):0.03125
# ('much', 'broader'):0.034482758620689655
# ('broader', 'univers'):1.0
# ('univers', 'without'):0.125
# ...
# ('hero', 'villain'):0.1111111111111111
# ('villain', 'villain'):0.05555555555555555
# ('villain', 'born'):0.05555555555555555
# ('born', 'bad'):0.5
# ('bad', 'environ'):0.05263157894736842
# ('environ', 'rais'):1.0
# ('rais', 'make'):0.3333333333333333
# ('make', 'dont'):0.018867924528301886
# ('need', 'elabor'):0.047619047619047616
# ('elabor', 'masterpiec'):1.0
# ('masterpiec', 'perform'):0.043478260869565216
# ('perform', 'highest'):0.018867924528301886
# ('highest', 'order'):0.5
# ('order', 'psycholog'):0.5
# ('psycholog', 'revolutionari'):0.1
# ('revolutionari', 'portray'):1.0
# ('portray', 'derang'):0.058823529411764705
# ('derang', 'charact'):0.3333333333333333
# ('charact', 'sinc'):0.015625
# ('sinc', 'joaquin'):0.1
# ('phoenix', 'announc'):0.01098901098901099
# ('announc', 'play'):0.5
# ('play', 'joke'):0.07142857142857142
# ('joke', 'front'):0.0064516129032258064
# ('front', 'hope'):0.3333333333333333
# ('hope', 'train'):0.05
# ('train', 'usual'):0.2
# ('usual', 'lead'):0.1111111111111111
# ('lead', 'disappoint'):0.125
# ('disappoint', 'time'):1.0
# ('movi', 'gritti'):0.005076142131979695
# ('gritti', 'realist'):0.14285714285714285
# ('realist', 'attitud'):0.09090909090909091
# ('attitud', 'toward'):1.0
# ('toward', 'girlfriend'):0.14285714285714285
# ('girlfriend', 'clue'):1.0
# ('clue', 'comic'):1.0
# ('comic', 'batman'):0.038461538461538464
# ('batman', 'drag'):0.041666666666666664
# ('drag', 'along'):0.3333333333333333
# ('along', 'ask'):0.2
# ('ask', 'base'):0.5
# ('base', 'true'):0.2
# ('true', 'stori'):0.14285714285714285
# ('stori', 'ye'):0.03125
# ('ye', 'similar'):0.16666666666666666
# ('driver', 'fight'):0.043478260869565216
# ('club', 'king'):0.5
# ('comedi', 'obviou'):0.06666666666666667
# ('obviou', 'doesn'):0.5
# ('doesn', 'hurt'):0.07692307692307693
# ('hurt', 'movi'):0.3333333333333333
# ('movi', 'thing'):0.005076142131979695
# ('thing', 'might'):0.045454545454545456
# ('might', 'see'):0.0625
# ('see', 'come'):0.02631578947368421
# ('come', 'usual'):0.05263157894736842
# ('usual', 'hate'):0.1111111111111111
# ('movi', 'manag'):0.005076142131979695
# ('manag', 'leav'):0.16666666666666666
# ('leav', 'question'):0.125
# ('question', 'open'):0.125
# ('open', 'answer'):0.2
# ('answer', 'enjoy'):0.5
# ('enjoy', 'doesn'):0.07692307692307693
# ('doesn', 'end'):0.07692307692307693
# ('end', 'movi'):0.1
# ('movi', 'finish'):0.005076142131979695
# ('finish', 'debat'):0.3333333333333333
# ('debat', 'theori'):1.0
# ('theori', 'hour'):1.0
# ('hour', 'keep'):0.2
# ('keep', 'review'):0.1111111111111111
# ('review', 'alway'):0.043478260869565216
# ('alway', 'spoil'):0.125
# ('spoil', 'free'):1.0
# ('free', 'anna'):0.3333333333333333
# ('anna', 'mention'):1.0
# ('mention', 'see'):0.25
# ('see', 'tri'):0.02631578947368421
# ('tri', 'told'):0.08333333333333333
# ('movi', 'sequel'):0.005076142131979695
# ('sequel', 'watch'):1.0
# ('watch', 'you'):0.022222222222222223
# ('you', 'understand'):0.1111111111111111
# ('understand', 'love'):0.09090909090909091
# ('love', 'charact'):0.05555555555555555
# ('studi', 'instant'):0.1111111111111111
# ('instant', 'classic'):1.0
# ('classic', 'never'):0.16666666666666666
# ('never', 'get'):0.05
# ('get', 'old'):0.017857142857142856
# ('old', '11'):0.3333333333333333
# ('11', 'year'):0.5
# ('year', 'heath'):0.041666666666666664
# ('ledger', 'might'):0.058823529411764705
# ('might', 'next'):0.0625
# ('next', 'joke'):0.25
# ('joke', 'walk'):0.0064516129032258064
# ('walk', 'away'):0.25
# ('away', 'littl'):0.16666666666666666
# ('littl', 'golden'):0.1
# ('golden', 'man'):1.0
# ('man', 'least'):0.041666666666666664
# ('least', 'nomin'):0.08333333333333333
# ('nomin', 'seem'):0.125
# ('seem', 'guarante'):0.05263157894736842
# ('guarante', 'can'):1.0
# ('can', 'stress'):0.08333333333333333
# ('stress', 'enough'):1.0
# ('enough', 'much'):0.2
# ('enjoy', 'approach'):0.07692307692307693
# ('approach', 'would'):0.3333333333333333
# ('would', 'love'):0.02857142857142857
# ('love', 'see'):0.05555555555555555
# ('see', 'kind'):0.02631578947368421
# ('kind', 'move'):0.06666666666666667
# ('move', 'comic'):0.023809523809523808
# ('comic', 'adapt'):0.038461538461538464
# ('adapt', 'realli'):0.25
# ('realli', 'deserv'):0.02857142857142857
# ('deserv', 'brazier'):0.058823529411764705
# ('brazier', 'one'):0.3333333333333333
# ('one', 'one'):0.015151515151515152
# ('one', 'abl'):0.015151515151515152
# ('abl', 'adapt'):0.14285714285714285
# ('adapt', 'without'):0.25
# ('without', 'contradict'):0.058823529411764705
# ('contradict', 'condit'):1.0
# ('condit', 'cynic'):0.125
# ('cynic', 'violent'):0.5
# ('violent', 'moral'):0.06666666666666667
# ('moral', 'corrupt'):0.25
# ('corrupt', 'time'):0.2
# ('time', 'one'):0.016129032258064516
# ('one', 'react'):0.015151515151515152
# ('react', 'condit'):0.5
# ('condit', 'uncompromis'):0.125
# ('uncompromis', 'insan'):1.0
# ('insan', 'fight'):0.125
# ('fight', 'back'):0.2
# ('back', 'use'):0.1111111111111111
# ('use', 'weapon'):0.09090909090909091
# ('weapon', 'reveng'):1.0
# ('reveng', 'reflect'):1.0
# ('reflect', 'world'):0.5
# ('world', 'mad'):0.05263157894736842
# ('mad', 'insan'):0.09090909090909091
# ('insan', 'grimac'):0.125
# ('grimac', 'disturb'):1.0
# ('disturb', 'question'):0.05263157894736842
# ('question', 'film'):0.125
# ('film', 'pose'):0.006024096385542169
# ('pose', 'figur'):1.0
# ('figur', 'joke'):0.5
# ('joke', 'equal'):0.0064516129032258064
# ('equal', 'fascin'):0.25
# ('fascin', 'frighten'):1.0
# ('frighten', 'piti'):0.5
# ('piti', 'embodi'):0.5
# ('embodi', 'phoenix'):0.3333333333333333
# ('phoenix', 'unforgett'):0.01098901098901099
# ('unforgett', 'perform'):0.5
# ('perform', 'great'):0.018867924528301886
# ('great', 'depth'):0.02564102564102564
# ('depth', 'wide'):0.2
# ('wide', 'rang'):0.5
# ('emot', 'train'):0.07692307692307693
# ('sickl', 'must'):0.3333333333333333
# ('must', 'centuri'):0.16666666666666666
# ('centuri', 'robert'):0.5
# ('no', 'pay'):0.1111111111111111
# ('pay', 'tribut'):0.3333333333333333
# ('tribut', '43'):0.3333333333333333
# ('43', 'year'):1.0
# ('year', 'later'):0.041666666666666664
# ('later', 'legendari'):0.25
# ('perform', 'taxi'):0.018867924528301886
# ('driver', 'kind'):0.043478260869565216
# ('kind', 'joke'):0.06666666666666667
# ('joke', 'kind'):0.0064516129032258064
# ('kind', 'cri'):0.06666666666666667
# ('cri', 'insid'):0.25
# ('insid', 'gothic'):0.5
# ('gothic', 'horror'):0.058823529411764705
# ('horror', 'director'):0.125
# ('director', 'courier'):0.06666666666666667
# ('courier', 'told'):1.0
# ('phillip', 'gone'):0.027777777777777776
# ('gone', 'martin'):0.3333333333333333
# ('scorses', 'filmographi'):0.25
# ('filmographi', 'rang'):1.0
# ('rang', 'taxi'):0.25
# ('comedi', 'bring'):0.06666666666666667
# ('bring', 'dead'):0.08333333333333333
# ('dead', 'shutter'):0.5
# ('shutter', 'island'):1.0
# ('island', 'robert'):1.0
# ('no', 'appear'):0.1111111111111111
# ('appear', 'chat'):0.14285714285714285
# ('chat', 'show'):1.0
# ('host', 'drive'):0.25
# ('drive', 'home'):0.25
# ('home', 'score'):0.25
# ('score', 'connect'):0.038461538461538464
# ('connect', 'joke'):0.25
# ('joke', 'deliv'):0.0064516129032258064
# ('deliv', 'braveri'):0.125
# ('braveri', 'perform'):1.0
# ('fleck', 'one'):0.034482758620689655
# ('one', 'life'):0.015151515151515152
# ('life', 'lose'):0.041666666666666664
# ('lose', 'unabl'):0.2
# ('unabl', 'hold'):1.0
# ('job', 'clown'):0.1
# ('clown', 'seven'):0.06666666666666667
# ('seven', 'differ'):0.5
# ('differ', 'kind'):0.058823529411764705
# ('kind', 'medit'):0.06666666666666667
# ('medit', 'still'):0.25
# ('still', 'panic'):0.1111111111111111
# ('panic', 'depress'):1.0
# ('depress', 'set'):0.2
# ('set', 'earli'):0.05555555555555555
# ('earli', '1980'):0.3333333333333333
# ('1980', 'gothic'):1.0
# ('citi', 'skewer'):0.06666666666666667
# ('skewer', 'fight'):1.0
# ('fight', 'giant'):0.2
# ('giant', 'rat'):1.0
# ('rat', 'social'):0.3333333333333333
# ('servic', 'fund'):0.2
# ('fund', 'cut'):1.0
# ('cut', 'mean'):0.3333333333333333
# ('mean', 'fleck'):0.058823529411764705
# ('fleck', 'social'):0.034482758620689655
# ('social', 'worker'):0.125
# ('worker', 'even'):0.5
# ('even', 'listen'):0.03125
# ('listen', 'go'):0.5
# ('go', 'like'):0.05555555555555555
# ('like', 'train'):0.016666666666666666
# ('sickl', 'fleck'):0.3333333333333333
# ('fleck', 'snap'):0.034482758620689655
# ('snap', 'reborn'):0.3333333333333333
# ('reborn', 'joke'):1.0
# ('joke', 'polit'):0.0064516129032258064
# ('polit', 'nihilist'):0.25
# ('nihilist', 'slow'):0.3333333333333333
# ('slow', 'burn'):0.1
# ('burn', 'drama'):0.5
# ('drama', 'take'):0.1
# ('take', 'aim'):0.038461538461538464
# ('aim', 'wealthi'):0.5
# ('wealthi', 'democrat'):1.0
# ('democrat', 'republican'):1.0
# ('republican', 'politician'):1.0
# ('politician', 'alik'):0.5
# ('alik', 'thoma'):0.5
# ('wayn', 'might'):0.07692307692307693
# ('might', 'paint'):0.0625
# ('paint', 'tramp'):0.2
# ('tramp', 'rich'):0.3333333333333333
# ('rich', 'tucson'):0.14285714285714285
# ('tucson', 'think'):1.0
# ('think', 'not'):0.02564102564102564
# ('not', 'clown'):0.16666666666666666
# ('clown', 'watch'):0.06666666666666667
# ('watch', 'scene'):0.022222222222222223
# ('scene', 'soul'):0.05263157894736842
# ('soul', 'dress'):0.5
# ('dress', 'tuxedo'):1.0
# ('tuxedo', 'watch'):1.0
# ('watch', 'screen'):0.022222222222222223
# ('screen', 'chain'):0.125
# ('movi', 'comment'):0.005076142131979695
# ('comment', 'desper'):1.0
# ('desper', 'condit'):1.0
# ('condit', 'mani'):0.125
# ('peopl', 'face'):0.022222222222222223
# ('face', '1930'):0.1111111111111111
# ('1930', 'depress'):1.0
# ('depress', 'joke'):0.2
# ('bold', 'comic'):0.5
# ('comic', 'strip'):0.038461538461538464
# ('strip', 'adapt'):0.5
# ('adapt', 'low'):0.25
# ('low', 'wastag'):0.25
# ('wastag', 'film'):1.0
# ('film', 'plot'):0.006024096385542169
# ('plot', 'tribut'):0.0625
# ('tribut', 'act'):0.3333333333333333
# ('act', 'score'):0.023255813953488372
# ('score', 'move'):0.038461538461538464
# ('move', 'inspir'):0.023809523809523808
# ('inspir', 'watch'):0.14285714285714285
# ('watch', 'movi'):0.022222222222222223
# ('movi', 'ah'):0.005076142131979695
# ('ah', 'told'):1.0
# ('phillip', 'joaquin'):0.027777777777777776
# ('phoenix', 'boom'):0.01098901098901099
# ('boom', 'theater'):1.0
# ('theater', 'hat'):0.3333333333333333
# ('hat', 'sir'):1.0
# ('sir', 'titl'):1.0
# ('titl', 'worst'):0.2
# ('worst', 'possibl'):0.5
# ('possibl', 'situat'):0.125
# ('situat', 'solv'):0.3333333333333333
# ('solv', 'wors'):1.0
# ('wors', 'way'):0.2
# ('way', 'possibl'):0.02857142857142857
# ('possibl', 'peopl'):0.125
# ('like', 'wonder'):0.016666666666666666
# ('wonder', 'world'):0.125
# ('world', 'piec'):0.05263157894736842
# ('piec', 'cap'):0.1111111111111111
# ('cap', 'today'):0.5
# ('today', 'go'):0.2
# ('go', 'wors'):0.05555555555555555
# ('wors', 'day'):0.2
# ('day', 'deserv'):0.14285714285714285
# ('deserv', 'extinct'):0.058823529411764705
# ('extinct', 'joaquin'):1.0
# ('phoenix', 'transform'):0.01098901098901099
# ('transform', 'tubular'):0.3333333333333333
# ('charact', 'give'):0.015625
# ('perform', 'worthi'):0.018867924528301886
# ('worthi', 'oscar'):0.2
# ('oscar', 'artist'):0.047619047619047616
# ('artist', 'word'):0.25
# ('use', 'describ'):0.09090909090909091
# ('describ', 'joke'):0.3333333333333333
# ('joke', 'grim'):0.0064516129032258064
# ('grim', 'product'):0.3333333333333333
# ('product', 'design'):0.2
# ('design', 'holder'):0.14285714285714285
# ('guðnadóttir', 'abstract'):0.5
# ('abstract', 'score'):1.0
# ('score', 'strong'):0.038461538461538464
# ('strong', 'social'):0.3333333333333333
# ('social', 'messag'):0.125
# ('messag', 'joke'):0.1111111111111111
# ('joke', 'depart'):0.0064516129032258064
# ('depart', 'recent'):1.0
# ('recent', 'comicbook'):0.25
# ('comicbook', 'move'):0.5
# ('move', 'grim'):0.023809523809523808
# ('grim', 'intens'):0.3333333333333333
# ('intens', 'drama'):0.5
# ('drama', 'homag'):0.1
# ('homag', 'scorses'):0.5
# ('scorses', 'lick'):0.25
# ('lick', 'lawless'):0.5
# ('lawless', 'in'):0.16666666666666666
# ('need', 'freak'):0.047619047619047616
# ('freak', 'mani'):1.0
# ('mani', 'u'):0.03571428571428571
# ('u', 'play'):0.0625
# ('role', 'put'):0.07692307692307693
# ('put', 'mask'):0.08333333333333333
# ('mask', 'pretend'):0.5
# ('pretend', 'like'):1.0
# ('like', 'good'):0.016666666666666666
# ('good', 'normal'):0.023255813953488372
# ('normal', 'deep'):0.5
# ('deep', 'insid'):0.16666666666666666
# ('insid', 'joke'):0.5
# ('masterpiec', 'join'):0.043478260869565216
# ('join', 'incred'):0.5
# ('incred', 'dont'):0.058823529411764705
# ('think', 'anyon'):0.02564102564102564
# ('done', 'movi'):0.08333333333333333
# ('movi', 'well'):0.005076142131979695
# ('well', 'he'):0.05555555555555555
# ('he', 'play'):0.14285714285714285
# ('role', 'real'):0.07692307692307693
# ('life', 'outcast'):0.041666666666666664
# ('outcast', 'saw'):0.3333333333333333
# ('saw', 'cinema'):0.3333333333333333
# ('cinema', 'came'):0.07142857142857142
# ('came', 'speechless'):0.16666666666666666
# ('speechless', 'act'):0.5
# ('incred', 'good'):0.058823529411764705
# ('say', 'might'):0.023255813953488372
# ('might', 'actual'):0.0625
# ('actual', 'act'):0.1111111111111111
# ('act', 'in'):0.023255813953488372
# ('in', 'give'):0.08333333333333333
# ('give', 'full'):0.038461538461538464
# ('full', 'credit'):0.14285714285714285
# ('credit', 'stori'):0.25
# ('stori', 'product'):0.03125
# ('product', 'act'):0.2
# ('act', 'lawless'):0.023255813953488372
# ('lawless', 'warn'):0.16666666666666666
# ('warn', 'mental'):0.5
# ('ill', 'featur'):0.037037037037037035
# ('featur', 'heavili'):0.2
# ('heavili', 'movi'):0.5
# ('movi', 'use'):0.005076142131979695
# ('use', 'discret'):0.09090909090909091
# ('discret', 'subject'):1.0
# ('subject', 'upset'):0.3333333333333333
# ('upset', 'movi'):1.0
# ('audienc', 'like'):0.09090909090909091
# ('joke', 'hate'):0.0064516129032258064
# ('hate', 'thoma'):0.125
# ('wayn', 'batman'):0.07692307692307693
# ('batman', 'father'):0.041666666666666664
# ('father', 'see'):0.5
# ('see', 'near'):0.02631578947368421
# ('near', 'movi'):0.1111111111111111
# ('movi', 'go'):0.005076142131979695
# ('go', 'classic'):0.05555555555555555
# ('classic', 'hope'):0.16666666666666666
# ('hope', 'first'):0.05
# ('first', 'say'):0.058823529411764705
# ('say', 'would'):0.023255813953488372
# ('would', 'offici'):0.02857142857142857
# ('offici', 'rate'):1.0
# ('rate', '9'):0.14285714285714285
# ('9', 'doesn'):1.0
# ('doesn', 'quit'):0.07692307692307693
# ('quit', 'last'):0.0625
# ('time', 'great'):0.016129032258064516
# ('score', '10'):0.038461538461538464
# ('10', 'reserv'):0.14285714285714285
# ('reserv', 'reason'):1.0
# ('reason', 'gave'):0.16666666666666666
# ('gave', 'and'):0.2
# ('and', 'person'):1.0
# ('person', 'see'):0.08333333333333333
# ('see', 'much'):0.02631578947368421
# ('much', 'depict'):0.034482758620689655
# ('depict', 'film'):1.0
# ('film', 'real'):0.006024096385542169
# ('life', 'doubt'):0.041666666666666664
# ('doubt', 'mani'):0.25
# ('mani', 'unlaw'):0.03571428571428571
# ('unlaw', 'act'):1.0
# ('act', 'carri'):0.023255813953488372
# ('carri', 'push'):0.3333333333333333
# ('edg', 'societi'):0.125
# ('societi', 'real'):0.02857142857142857
# ('world', 'film'):0.05263157894736842
# ('film', 'gener'):0.006024096385542169
# ('gener', 'charact'):0.3333333333333333
# ('charact', 'resent'):0.015625
# ('resent', 'differ'):1.0
# ('differ', 'way'):0.058823529411764705
# ('way', 'clear'):0.02857142857142857
# ('clear', 'intens'):0.2
# ('intens', 'depict'):0.5
# ('film', 'mean'):0.006024096385542169
# ('mean', 'small'):0.058823529411764705
# ('small', 'way'):0.5
# ('way', 'imagin'):0.02857142857142857
# ('imagin', 'could'):0.25
# ('could', 'life'):0.037037037037037035
# ('life', 'courag'):0.041666666666666664
# ('courag', 'could'):1.0
# ('could', 'go'):0.037037037037037035
# ('go', 'question'):0.05555555555555555
# ('question', 'whether'):0.125
# ('whether', 'enough'):0.25
# ('enough', 'stem'):0.2
# ('stem', 'cycl'):1.0
# ('cycl', 'abus'):0.5
# ('abus', 'crime'):0.2
# ('crime', 'societi'):0.125
# ('societi', 'much'):0.02857142857142857
# ('much', 'cover'):0.034482758620689655
# ('cover', 'also'):1.0
# ('also', 'get'):0.037037037037037035
# ('get', 'bit'):0.017857142857142856
# ('bit', 'philosoph'):0.125
# ('philosoph', 'mean'):1.0
# ('mean', 'say'):0.058823529411764705
# ('say', 'think'):0.023255813953488372
# ('think', 'matter'):0.02564102564102564
# ('matter', 'academ'):0.25
# ('academ', 'far'):1.0
# ('far', 'issu'):0.047619047619047616
# ('issu', 'leg'):0.14285714285714285
# ('leg', 'question'):1.0
# ('question', 'manag'):0.125
# ('manag', 'regul'):0.16666666666666666
# ('regul', 'societi'):1.0
# ('societi', 'might'):0.02857142857142857
# ('sure', 'yet'):0.047619047619047616
# ('yet', 'hit'):0.1111111111111111
# ('hard', 'hit'):0.14285714285714285
# ('hit', 'deep'):0.16666666666666666
# ('deep', 'care'):0.16666666666666666
# ('care', 'look'):0.14285714285714285

# %%
whole_dataset = ''
index = []
i = 1
for line in df['After Lemmatization']:
  whole_dataset = whole_dataset + line
  value = 'Review-' + str(i)
  index.append(value)
  i += 1

# %%
import nltk
nltk.download('brown')
from textblob import TextBlob
noun_phrases = []
frequency = []
for line in df['After Lemmatization']:
  blob = TextBlob(line)
  for nouns in blob.noun_phrases:
    noun_phrases.append(nouns)
for word in noun_phrases:
  noun_phrases_freq = []
  for line in df['After Lemmatization']:
    noun_phrases_freq.append(line.count(word) / whole_dataset.count(word))
  frequency.append(noun_phrases_freq)
noun_phrases_df = pd.DataFrame(frequency).T
noun_phrases_df.columns = list(noun_phrases)
noun_phrases_df.index = index
noun_phrases_df
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
#             physic pain experi good way  film year review flood wa  \
# Review-1                            0.0                        0.0
# Review-2                            1.0                        0.0
# Review-3                            0.0                        1.0
# Review-4                            0.0                        0.0
# Review-5                            0.0                        0.0
# ...                                 ...                        ...
# Review-121                          0.0                        0.0
# Review-122                          0.0                        0.0
# Review-123                          0.0                        0.0
# Review-124                          0.0                        0.0
# Review-125                          0.0                        0.0
#
#             hope excit movi walk cinema  hollow empti continu  film year  \
# Review-1                            0.0                   0.0        0.0
# Review-2                            0.0                   0.0        0.0
# Review-3                            1.0                   1.0        0.5
# Review-4                            0.0                   0.0        0.0
# Review-5                            0.0                   0.0        0.0
# ...                                 ...                   ...        ...
# Review-121                          0.0                   0.0        0.0
# Review-122                          0.0                   0.0        0.0
# Review-123                          0.0                   0.0        0.0
# Review-124                          0.0                   0.0        0.0
# Review-125                          0.0                   0.0        0.0
#
#             real masterpiec cinematographi excel act  \
# Review-1                                         0.0
# Review-2                                         0.0
# Review-3                                         1.0
# Review-4                                         0.0
# Review-5                                         0.0
# ...                                              ...
# Review-121                                       0.0
# Review-122                                       0.0
# Review-123                                       0.0
# Review-124                                       0.0
# Review-125                                       0.0
#
#             sidecharact bland overlay dramat plot heavili relief plottwist film  \
# Review-1                                                  0.0
# Review-2                                                  0.0
# Review-3                                                  1.0
# Review-4                                                  0.0
# Review-5                                                  0.0
# ...                                                       ...
# Review-121                                                0.0
# Review-122                                                0.0
# Review-123                                                0.0
# Review-124                                                0.0
# Review-125                                                0.0
#
#             harsh actual fall flat  good point  phoenix phenomenon score  ...  \
# Review-1                       0.0         0.0                       0.0  ...
# Review-2                       0.0         0.0                       0.0  ...
# Review-3                       1.0         1.0                       1.0  ...
# Review-4                       0.0         0.0                       0.0  ...
# Review-5                       0.0         0.0                       0.0  ...
# ...                            ...         ...                       ...  ...
# Review-121                     0.0         0.0                       0.0  ...
# Review-122                     0.0         0.0                       0.0  ...
# Review-123                     0.0         0.0                       0.0  ...
# Review-124                     0.0         0.0                       0.0  ...
# Review-125                     0.0         0.0                       0.0  ...
#
#             real world film gener charact  differ way  \
# Review-1                              0.0         0.0
# Review-2                              0.0         0.0
# Review-3                              0.0         0.0
# Review-4                              0.0         0.0
# Review-5                              0.0         0.0
# ...                                   ...         ...
# Review-121                            0.0         0.0
# Review-122                            0.0         0.0
# Review-123                            0.0         0.0
# Review-124                            0.0         0.0
# Review-125                            1.0         1.0
#
#             clear intens depict film  small way imagin  life courag  \
# Review-1                         0.0               0.0          0.0
# Review-2                         0.0               0.0          0.0
# Review-3                         0.0               0.0          0.0
# Review-4                         0.0               0.0          0.0
# Review-5                         0.0               0.0          0.0
# ...                              ...               ...          ...
# Review-121                       0.0               0.0          0.0
# Review-122                       0.0               0.0          0.0
# Review-123                       0.0               0.0          0.0
# Review-124                       0.0               0.0          0.0
# Review-125                       1.0               1.0          1.0
#
#             stem cycl abus crime societi  bit philosoph  matter academ  \
# Review-1                             0.0            0.0            0.0
# Review-2                             0.0            0.0            0.0
# Review-3                             0.0            0.0            0.0
# Review-4                             0.0            0.0            0.0
# Review-5                             0.0            0.0            0.0
# ...                                  ...            ...            ...
# Review-121                           0.0            0.0            0.0
# Review-122                           0.0            0.0            0.0
# Review-123                           0.0            0.0            0.0
# Review-124                           0.0            0.0            0.0
# Review-125                           1.0            1.0            1.0
#
#             issu leg question manag regul societi  deep care look
# Review-1                                      0.0             0.0
# Review-2                                      0.0             0.0
# Review-3                                      0.0             0.0
# Review-4                                      0.0             0.0
# Review-5                                      0.0             0.0
# ...                                           ...             ...
# Review-121                                    0.0             0.0
# Review-122                                    0.0             0.0
# Review-123                                    0.0             0.0
# Review-124                                    0.0             0.0
# Review-125                                    1.0             1.0
#
# [125 rows x 1471 columns]

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (20 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
# Write your code here
import math
def tf_idf_value(sentence,word):
  size = len(sentence.split(" "))
  tf_value = sentence.count(word)/size
  idf_value = 0
  if(tf_value!=0):
    idf_value = math.log(size)/sentence.count(word)
  else:
    return 0;
  return tf_value*idf_value

sentences = df["Spelling Correction"].values.tolist()
tokens_list = set([j for i in sentences for j in i.split(" ")])
tf_idf = pd.DataFrame(tokens_list,columns=["token"])
count = 0
for i in sentences:
  tf_idf[str(count)] = tf_idf["token"].apply(lambda x : tf_idf_value(i,x))
  count+=1

tf_idf
# Out:
# <ipython-input-16-ac2e148a9571>:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   tf_idf[str(count)] = tf_idf["token"].apply(lambda x : tf_idf_value(i,x))
#            token    0         1         2         3         4         5  \
# 0                 0.0  0.244136  0.064221  0.055855  0.035297  0.110774
# 1        critics  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2           tell  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 3        outcast  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 4      unnatural  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# ...          ...  ...       ...       ...       ...       ...       ...
# 2910       focus  0.0  0.000000  0.000000  0.000000  0.035297  0.000000
# 2911   enjoyable  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2912  believable  0.0  0.000000  0.000000  0.055855  0.000000  0.000000
# 2913        fail  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2914        that  0.0  0.000000  0.064221  0.055855  0.000000  0.000000
#
#              6         7         8  ...       115      116  117       118  \
# 0     0.058163  0.081918  0.093937  ...  0.035297  0.21799  0.0  0.149787
# 1     0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
# 2     0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
# 3     0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
# 4     0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
# ...        ...       ...       ...  ...       ...      ...  ...       ...
# 2910  0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
# 2911  0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
# 2912  0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
# 2913  0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
# 2914  0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.0  0.000000
#
#       119       120       121       122       123      124
# 0     0.0  0.099542  0.103716  0.116114  0.180537  0.04957
# 1     0.0  0.000000  0.000000  0.000000  0.000000  0.00000
# 2     0.0  0.000000  0.000000  0.000000  0.000000  0.00000
# 3     0.0  0.000000  0.103716  0.000000  0.000000  0.00000
# 4     0.0  0.000000  0.000000  0.000000  0.000000  0.00000
# ...   ...       ...       ...       ...       ...      ...
# 2910  0.0  0.000000  0.000000  0.000000  0.000000  0.00000
# 2911  0.0  0.000000  0.000000  0.000000  0.000000  0.00000
# 2912  0.0  0.000000  0.000000  0.000000  0.000000  0.00000
# 2913  0.0  0.000000  0.000000  0.000000  0.000000  0.00000
# 2914  0.0  0.000000  0.000000  0.000000  0.000000  0.00000
#
# [2915 rows x 126 columns]

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
query_sentence = 'Shang-Chi and the Legend of the Ten Rings is an Action - Fantasy movie in which we watch a new era of Marvel Studios rise with Shang-Chi,the master of Kung Fu. He has to face his past involving him with the Ten Rings organization and crate his future accordingly.Finally, I have to say that "Shang-Chi and the Legend of the Ten Rings" is an amazing movie and I strongly recommend everyone to watch it, especially the fans of Marvel.'
X_list = word_tokenize(query_sentence)
sw = stopwords.words('english') 
X_set = {w for w in X_list if not w in sw}

# %%
def compute_vector(X_set, Y_set):
  rvector = X_set.union(Y_set)
  l1 =[];l2 =[]
  for w in rvector: 
      if w in X_set: l1.append(1)
      else: l1.append(0) 
      if w in Y_set: l2.append(1) 
      else: l2.append(0)
  return rvector, l1, l2

# %%
def compute_cosine(rvector, l1, l2):
  c = 0
  for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
  cosine = c / float((sum(l1)*sum(l2))**0.5) 
  return cosine

# %%
similarity_list = []
for sentence in df['Spelling Correction']:
  Y_list = word_tokenize(sentence)
  Y_set = {w for w in Y_list if not w in sw}
  rvector, l1, l2 = compute_vector(X_set, Y_set)
  try:
    similarity = compute_cosine(rvector, l1, l2)
  except ZeroDivisionError:
    similarity = 'None'
  similarity_list.append(similarity)
cosine_dataframe = pd.DataFrame(list(zip(df['Review'],similarity_list)), columns=['Reviews','Cosine Similarity'])
cosine_dataframe
# Out:
#                                                Reviews Cosine Similarity
# 0                                                                   None
# 1    The movie affects you in a way that makes it p...          0.058124
# 2    When I heard everyone saying that this is the ...          0.091192
# 3    Truly a masterpiece, The Best Hollywood film o...               0.0
# 4    I have seen Joker yesterday at Venice an early...          0.030268
# ..                                                 ...               ...
# 120  Joaquin Phoenix transforms into the titular ch...               0.0
# 121  And I'm not saying you need to be a freak. Man...          0.030015
# 122  Saw this at the cinema and came out speechless...          0.064483
# 123  This is the movie where the audience will like...          0.043937
# 124  First just to say that I would officially rate...          0.037716
#
# [125 rows x 2 columns]

# %% [markdown]
# # **Question 3: Create your own word embedding model**

# %% [markdown]
# (20 points). Use the data you collected for assignment two to build a word embedding model:
#
# (1) Train a 300-dimension word embedding (it can be word2vec, glove, ulmfit, bert, or others).
#
# (2) Visualize the word embedding model you created.
#
# Reference: https://machinelearningmastery.com/develop-word-embeddings-python-gensim/
#
# Reference: https://jaketae.github.io/study/word2vec/

# %%
# Write your code here

# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# chromium-chromedriver is already the newest version (108.0.5359.71-0ubuntu0.18.04.5).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: selenium in /usr/local/lib/python3.8/dist-packages (4.7.2)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.8/dist-packages (from selenium) (2022.9.24)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.8/dist-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in /usr/local/lib/python3.8/dist-packages (from selenium) (1.26.13)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.8/dist-packages (from selenium) (0.22.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.8/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
from selenium import webdriver #importing selenium package
options = webdriver.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %%
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.by import By
import pandas as pd
import time

driver = webdriver.Chrome('chromedriver',options=options)
link = 'https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv'
title_array = []
review_array = []
driver.get(link)
for num in range(4):
  driver.find_element(By.CLASS_NAME,"ipl-load-more__button").click()
  time.sleep(5)
  listOfTitle = driver.find_elements(By.CLASS_NAME, "title")
  listOfReviews = driver.find_elements(By.CLASS_NAME, "text")
for ele, sub_ele in zip(listOfTitle, listOfReviews):
      title_array.append((ele.text).replace('\n',''))
      review_array.append(sub_ele.text)
df = pd.DataFrame(list(zip(title_array, review_array)), columns =['Title', 'Review'])
print("Length of data frame is {0}".format(len(df)))
df
# Out:
# Length of data frame is 125
#                                                  Title  \
# 0        I would not call it a masterpiece as some did
# 1        Not a spoon feeding of CGI fueled faux drama.
# 2                           Is it great? I don't know.
# 3                             Perfect in every aspect.
# 4    A psychological study, rather than a superhero...
# ..                                                 ...
# 120                            There Are No Capes Here
# 121  If you're an outcast, you'll understand this m...
# 122                   An experience as much as a movie
# 123  Incredible movie! And one of the best 2019 mov...
# 124                                       Scarily real
#
#                                                 Review
# 0
# 1    The movie affects you in a way that makes it p...
# 2    When I heard everyone saying that this is the ...
# 3    Truly a masterpiece, The Best Hollywood film o...
# 4    I have seen Joker yesterday at Venice an early...
# ..                                                 ...
# 120  Joaquin Phoenix transforms into the titular ch...
# 121  And I'm not saying you need to be a freak. Man...
# 122  Saw this at the cinema and came out speechless...
# 123  This is the movie where the audience will like...
# 124  First just to say that I would officially rate...
#
# [125 rows x 2 columns]

# %%
list2 = []
for i in df.index:
    y = str(df["Review"][i]).split()
    list2.append(y)

# %%
from gensim.models import Word2Vec
model2 = Word2Vec(list2, size = 300)
print(model2)
# Out:
# /usr/local/lib/python3.8/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# Word2Vec(vocab=483, size=300, alpha=0.025)

# %%
words2 = list(model2.wv.vocab)
words2
# Out:
# ['The',
#  'movie',
#  'you',
#  'in',
#  'a',
#  'way',
#  'that',
#  'makes',
#  'it',
#  'to',
#  'but',
#  'good',
#  'When',
#  'I',
#  'everyone',
#  'saying',
#  'this',
#  'is',
#  'the',
#  'film',
#  'of',
#  'and',
#  'all',
#  'reviews',
#  'with',
#  'was',
#  'quite',
#  'for',
#  'movie.',
#  'out',
#  'felt',
#  'me',
#  'say',
#  'this,',
#  'This',
#  'real',
#  'masterpiece.',
#  'cinematography',
#  'acting',
#  "that's",
#  'just',
#  'it.',
#  'are',
#  'plot',
#  'on',
#  'so',
#  'actually',
#  "it's",
#  'there',
#  'no',
#  'points',
#  'Phoenix',
#  'score',
#  'great.',
#  'also',
#  'incredible',
#  'not',
#  'great',
#  'at',
#  'all.',
#  'It',
#  'even',
#  'has',
#  'scenes',
#  'left',
#  'Best',
#  'one',
#  'films',
#  'And',
#  'truly',
#  'comic',
#  'book',
#  'Some',
#  'people',
#  'find',
#  "It's",
#  'about',
#  'society',
#  'those',
#  'they',
#  'can',
#  'do',
#  'something',
#  'shows',
#  'class',
#  'how',
#  'rich',
#  'others',
#  'around',
#  'them',
#  'what',
#  'There',
#  'could',
#  'be',
#  'multiple',
#  'our',
#  'much',
#  'than',
#  'making',
#  'up',
#  'first',
#  'film.',
#  'A',
#  'have',
#  'seen',
#  'Joker',
#  'an',
#  'We',
#  'had',
#  'some',
#  'definitely',
#  'worth',
#  'cinema',
#  'as',
#  'because',
#  'far',
#  'from',
#  'or',
#  'movie,',
#  'most',
#  'genre',
#  'main',
#  'character,',
#  'Joaquin',
#  'does',
#  'almost',
#  'take',
#  'both',
#  'good.',
#  'might',
#  'joker',
#  'while',
#  "Phoenix's",
#  'being',
#  'superhero',
#  'movies',
#  'Dark',
#  'Knight',
#  'easily',
#  'movies,',
#  'least',
#  'very',
#  'film,',
#  'cannot',
#  'feel',
#  'too',
#  'his',
#  'King',
#  'somewhat',
#  'am',
#  'see',
#  'more',
#  'by',
#  'Todd',
#  'best',
#  'only',
#  'should',
#  'get',
#  'why',
#  'hate',
#  'think',
#  'need',
#  'empathy',
#  "Arthur's",
#  'But',
#  'come',
#  'point',
#  'will',
#  'never',
#  'masterpiece',
#  'Phillips',
#  'amazing',
#  'enjoy',
#  'without',
#  'off',
#  'if',
#  "doesn't",
#  'Oscar',
#  'every',
#  'review',
#  'Is',
#  'here.',
#  'story',
#  'he',
#  'takes',
#  'time',
#  'came',
#  'like',
#  'Taxi',
#  'Driver',
#  'its',
#  'violent',
#  'going',
#  'needs',
#  'Director',
#  'performance',
#  'watch',
#  "won't",
#  'watching',
#  '-',
#  'same',
#  'time.',
#  'proper',
#  'psychological',
#  'single',
#  'character',
#  'ever',
#  'who',
#  'You',
#  'understand',
#  'character.',
#  'lot',
#  'violence.',
#  'each',
#  'us',
#  'become',
#  'better',
#  'make',
#  'other',
#  'sad',
#  'win',
#  'u',
#  'really',
#  'deep',
#  'interesting',
#  '5',
#  'To',
#  'your',
#  'close',
#  'put',
#  'many',
#  '10',
#  'here',
#  'If',
#  "can't",
#  'through',
#  '(or',
#  'then',
#  'you,',
#  'near',
#  'been',
#  'absolutely',
#  'quality',
#  'perfect',
#  'live',
#  'little',
#  'where',
#  'would',
#  'seem',
#  'new',
#  'we',
#  'DC',
#  'last',
#  'back',
#  'look',
#  'society,',
#  'mentally',
#  'ill',
#  'which',
#  'looking',
#  'feeling',
#  'fact',
#  'still',
#  'any',
#  'into',
#  'usually',
#  'Batman',
#  'moments',
#  'scene',
#  'these',
#  'times',
#  "wasn't",
#  'own',
#  'completely',
#  'universe',
#  'done',
#  "Don't",
#  "don't",
#  'problem',
#  'feels',
#  'someone',
#  'told',
#  "I'm",
#  'trying',
#  'yet',
#  'mental',
#  'illness',
#  'modern',
#  'long',
#  'watched',
#  'were',
#  'music',
#  'either',
#  'my',
#  'right',
#  'did',
#  'thought',
#  'maybe',
#  'getting',
#  'worse',
#  'made',
#  'use',
#  'social',
#  'media',
#  'life.',
#  'world',
#  'While',
#  "I've",
#  'down',
#  'often',
#  'So',
#  'They',
#  'mean',
#  'What',
#  'man',
#  'him',
#  'He',
#  'gave',
#  'deeply',
#  'gives',
#  'talk',
#  'Heath',
#  'portrayal',
#  'Joker,',
#  "isn't",
#  'disturbed',
#  'dark,',
#  'dark',
#  'love',
#  'villain',
#  'bad',
#  'always',
#  'overall',
#  'bit',
#  'throughout',
#  'In',
#  'though',
#  '10/10',
#  'based',
#  'already',
#  'want',
#  'further',
#  'acting,',
#  'cinematography,',
#  'sound',
#  'script',
#  'itself',
#  'deserves',
#  'that,',
#  'sure',
#  'anything',
#  'this.',
#  'kind',
#  'their',
#  'well',
#  'despite',
#  'disturbing',
#  'when',
#  'actor',
#  'iconic',
#  '&',
#  'nothing',
#  'such',
#  'soundtrack',
#  'beautiful',
#  'part',
#  'Joker.',
#  "we're",
#  'Phoenix,',
#  'him,',
#  'everything',
#  'audience',
#  'realistic',
#  'know',
#  'certain',
#  'That',
#  'able',
#  'you.',
#  'Gotham',
#  'clown',
#  'Arthur',
#  'Fleck',
#  '"Joker"',
#  'role',
#  'His',
#  'City',
#  'At',
#  'drama',
#  'person',
#  'becoming',
#  'system',
#  'wants',
#  'enough',
#  'give',
#  'director',
#  "didn't",
#  'job',
#  'towards',
#  'worked',
#  'along',
#  'Murray',
#  'show',
#  'slow',
#  'performances',
#  'Robert',
#  'De',
#  'Niro',
#  'unstable',
#  'gets',
#  'Thomas',
#  'Wayne',
#  'three',
#  'Phoenix.',
#  'actors',
#  'may',
#  'Just',
#  'shot',
#  'world.',
#  'seems',
#  'believable',
#  'laughter',
#  'rather',
#  'appears',
#  'him.',
#  'broken',
#  'known',
#  "could've",
#  'true',
#  'piece',
#  'action',
#  'cinematic',
#  'totally',
#  'Fleck,',
#  'hero',
#  'over',
#  'thing',
#  'since',
#  'it,',
#  'origin',
#  'after',
#  ':',
#  'films.',
#  'mind',
#  'means',
#  'things',
#  "there's",
#  'horror',
#  'Driver,',
#  "Joker's",
#  'serious',
#  'another',
#  'violence',
#  'For',
#  'Scorsese',
#  'different',
#  'expecting',
#  '...',
#  'As',
#  'few',
#  'years',
#  'delivers',
#  'care',
#  'classic',
#  'full',
#  'n',
#  'Yes,',
#  'within',
#  'edge',
#  'whole',
#  'himself',
#  'place',
#  'life',
#  'Of',
#  'legendary',
#  'between',
#  'gritty',
#  'study',
#  'perfectly',
#  'hope',
#  'anyone',
#  'go',
#  'flawless',
#  'i']

# %%
# fit a 2d PCA model to the vectors
from sklearn.decomposition import PCA

X = model2[model2.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# Out:
# <ipython-input-29-a9604118c014>:4: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   X = model2[model2.wv.vocab]

# %%
# create a scatter plot of the projection
import matplotlib.pyplot as plt
plt.figure (figsize = (20,20))
plt.scatter(result[:, 0], result[:, 1])
words = list(model2.wv.vocab)
for i, word in enumerate(words):
	plt.annotate(word, xy=(result[i, 0], result[i, 1]))
plt.show()

# %% [markdown]
# # **Question 4: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each review (abstract or tweet) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
# The GitHub link of your final csv file



# Link: 
https://github.com/shubhika1723/shubhika_INFO5731_Spring2020/blob/main/data.csv
